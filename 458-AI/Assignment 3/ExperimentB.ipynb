# %% [markdown]
# <img src="https://github.com/djp840/MSDS_458_Public/blob/master/images/NorthwesternHeader.png?raw=1">

# %% [markdown]
# ## MSDS458 Research Assignment 3

# %% [markdown]
# ## Data Preperation

# %% [markdown]
# ### Research Assignment Reporting Functions

# %%
# Accuracy and loss Line plots visual
def plot_history(history):
  losses = history.history['loss']
  accs = history.history['accuracy']
  val_losses = history.history['val_loss']
  val_accs = history.history['val_accuracy']
  epochs = len(losses)

  plt.figure(figsize=(16, 4))
  for i, metrics in enumerate(zip([losses, accs], [val_losses, val_accs], ['Loss', 'Accuracy'])):
    plt.subplot(1, 2, i + 1)
    plt.plot(range(epochs), metrics[0], label='Training {}'.format(metrics[2]))
    plt.plot(range(epochs), metrics[1], label='Validation {}'.format(metrics[2]))
    plt.legend()
  plt.show()

# %%
# Shows Accuracy & Root Mean Square Error scores
def print_validation_report(y_test, predictions):
    print("Classification Report")
    print(classification_report(y_test, predictions))
    print('Accuracy Score: {}'.format(accuracy_score(y_test, predictions)))
    print('Root Mean Square Error: {}'.format(np.sqrt(MSE(y_test, predictions))))

# %%
# Confusion Matrix visual
def plot_confusion_matrix(y_true, y_pred):
    mtx = confusion_matrix(y_true, y_pred)
    fig, ax = plt.subplots(figsize=(8,8))
    sns.heatmap(mtx, annot=True, fmt='d', linewidths=.75,  cbar=False, ax=ax,cmap='Blues',linecolor='white')
    #  square=True,
    plt.ylabel('true label')
    plt.xlabel('predicted label')

# %% [markdown]
# ### Import packages

# %%
import datetime
from datetime import datetime as dt 
from packaging import version
from collections import Counter
import numpy as np
import pandas as pd
import time
import string
import nltk
from nltk.corpus import stopwords
from collections import Counter
import re

import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

from sklearn.metrics import confusion_matrix, classification_report
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import mean_squared_error as MSE
from sklearn.metrics import accuracy_score

import tensorflow as tf
from tensorflow import keras
import tensorflow_datasets as tfds
from tensorflow.keras import layers
from tensorflow.keras.layers import TextVectorization

# %%
# %matplotlib inline
np.set_printoptions(precision=3, suppress=True)

# %% [markdown]
# ### Stopword Function

# %%
def custom_stopwords(input_text):
    lowercase = tf.strings.lower(input_text)
    stripped_punct = tf.strings.regex_replace(lowercase
                                  ,'[%s]' % re.escape(string.punctuation)
                                  ,'')
    return tf.strings.regex_replace(stripped_punct, r'\b(' + r'|'.join(STOPWORDS) + r')\b\s*',"")

# %% [markdown]
# ### Analyze AG_NEWS_SUBSET Data <br>
#
# AG is a collection of more than 1 million news articles. News articles have been gathered from more than 2000 news sources by ComeToMyHead in more than 1 year of activity. ComeToMyHead is an academic news search engine which has been running since July, 2004. The dataset is provided by the academic comunity for research purposes in data mining (clustering, classification, etc), information retrieval (ranking, search, etc), xml, data compression, data streaming, and any other non-commercial activity.<br>
#
# For more information, please refer to the link http://www.di.unipi.it/~gulli/AG_corpus_of_news_articles.html<br>
#
#
# The AG's news topic classification dataset is constructed by choosing 4 largest classes (**World**, **Sports**, **Business**, and **Sci/Tech**) from the original corpus. Each class contains 30,000 training samples and 1,900 testing samples. The total number of training samples is 120,000 and testing 7,600.<br>
#
# Homepage: https://arxiv.org/abs/1509.01626<br>
#
# Source code: tfds.text.AGNewsSubset
#
# Versions:
#
# 1.0.0 (default): No release notes.
# Download size: 11.24 MiB
#
# Dataset size: 35.79 MiB

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <b>More Technical</b>: Throughout the notebook. This types of boxes provide more technical details and extra references about what you are seeing. They contain helpful tips, but you can safely skip them the first time you run through the code.
# </div>

# %%
#!conda install -c anaconda tensorflow-datasets --y
#!pip install -c anaconda tensorflow-datasets --y

# %% [markdown]
# ### Load AG_NEWS_SUBSET News Articles Dataset

# %%
# register  ag_news_subset so that tfds.load doesn't generate a checksum (mismatch) error
# !python -m tensorflow_datasets.scripts.download_and_prepare --register_checksums --datasets=ag_news_subset

dataset, info = tfds.load('ag_news_subset', with_info=True,  split=['train[:114000]','train[114000:]', 'test'],
                          batch_size = 32, as_supervised=True)
train_ds, val_ds, test_ds = dataset
# Out:
# 2022-10-29 19:04:05.895223: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# W1029 19:04:05.895579 140115602253696 download_and_prepare.py:43] ***`tfds build` should be used instead of `download_and_prepare`.***
# INFO[build.py]: Loading dataset ag_news_subset from imports: tensorflow_datasets.text.ag_news_subset
# 2022-10-29 19:04:06.058382: W tensorflow/core/platform/cloud/google_auth_provider.cc:184] All attempts to get a Google authentication bearer token failed, returning an empty token. Retrieving token from files failed with "NOT_FOUND: Could not locate the credentials file.". Retrieving token from GCE failed with "NOT_FOUND: Error executing an HTTP request: HTTP response code 404".
# INFO[dataset_info.py]: Load pre-computed DatasetInfo (eg: splits, num examples,...) from GCS: ag_news_subset/1.0.0
# INFO[dataset_info.py]: Load dataset info from /tmp/tmpw8mwm3gutfds
# INFO[dataset_info.py]: Field info.splits from disk and from code do not match. Keeping the one from code.
# INFO[dataset_info.py]: Field info.supervised_keys from disk and from code do not match. Keeping the one from code.
# INFO[dataset_info.py]: Field info.module_name from disk and from code do not match. Keeping the one from code.
# INFO[build.py]: download_and_prepare for dataset ag_news_subset/1.0.0...
# INFO[dataset_builder.py]: Generating dataset ag_news_subset (/root/tensorflow_datasets/ag_news_subset/1.0.0)
# Downloading and preparing dataset 11.24 MiB (download: 11.24 MiB, generated: 35.79 MiB, total: 47.03 MiB) to /root/tensorflow_datasets/ag_news_subset/1.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
#
#
#
#
# INFO[download_manager.py]: Downloading https://drive.google.com/uc?export=download&id=0Bz8a_Dbh9QhbUDNpeUdjb0wxRms into /root/tensorflow_datasets/downloads/ucexport_download_id_0Bz8a_Dbh9QhbUDNpeUdjb0wxj4g1umFAV8OV-uDwxSJR0LdxO_k1jxMuFWwAfNX9jos.tmp.5833287cfec94a8683a1f3a1983b2712...
# Dl Completed...: 0 url [00:00, ? url/s]
#
# Extraction completed...: 0 file [00:00, ? file/s]
# Dl Completed...:   0% 0/1 [00:00<?, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
#
# Dl Completed...:   0% 0/1 [00:10<?, ? url/s]
# Dl Size...:   0% 0/11 [00:10<?, ? MiB/s]
#
# Extraction completed...: 0 file [00:10, ? file/s]
# Dl Completed...:   0% 0/1 [00:10<?, ? url/s]
# Dl Size...:   9% 1/11 [00:10<01:48, 10.89s/ MiB]
#
# Dl Completed...:   0% 0/1 [00:10<?, ? url/s]
# Dl Size...:  18% 2/11 [00:10<01:37, 10.89s/ MiB]
#
# Dl Completed...:   0% 0/1 [00:10<?, ? url/s]
# Dl Size...:  27% 3/11 [00:10<01:27, 10.89s/ MiB]
#
# Dl Completed...:   0% 0/1 [00:10<?, ? url/s]
# Dl Size...:  36% 4/11 [00:10<01:16, 10.89s/ MiB]
#
# Dl Completed...:   0% 0/1 [00:10<?, ? url/s]
# Dl Size...:  45% 5/11 [00:10<01:05, 10.89s/ MiB]
#
# Dl Completed...:   0% 0/1 [00:10<?, ? url/s]
# Dl Size...:  55% 6/11 [00:10<00:54, 10.89s/ MiB]
#
# Dl Completed...:   0% 0/1 [00:10<?, ? url/s]
# Dl Size...:  64% 7/11 [00:10<00:43, 10.89s/ MiB]
#
# Extraction completed...: 0 file [00:10, ? file/s]
# Dl Completed...:   0% 0/1 [00:10<?, ? url/s]
# Dl Size...:  73% 8/11 [00:10<00:03,  1.00s/ MiB]
#
# Dl Completed...:   0% 0/1 [00:10<?, ? url/s]
# Dl Size...:  82% 9/11 [00:10<00:02,  1.00s/ MiB]
#
# Dl Completed...:   0% 0/1 [00:11<?, ? url/s]
# Dl Size...:  91% 10/11 [00:11<00:01,  1.00s/ MiB]
#
# Dl Completed...:   0% 0/1 [00:11<?, ? url/s]
# Dl Size...: 100% 11/11 [00:11<00:00,  1.00s/ MiB]
#
# Dl Completed...: 100% 1/1 [00:11<00:00, 11.02s/ url]
# Dl Size...: 100% 11/11 [00:11<00:00,  1.00s/ MiB]
#
# Dl Completed...: 100% 1/1 [00:11<00:00, 11.02s/ url]
# Dl Size...: 100% 11/11 [00:11<00:00,  1.00s/ MiB]
#
# Extraction completed...:   0% 0/1 [00:11<?, ? file/s]
#
# Dl Completed...: 100% 1/1 [00:11<00:00, 11.02s/ url]
# Dl Size...: 100% 11/11 [00:11<00:00,  1.00s/ MiB]
#
# Extraction completed...: 100% 1/1 [00:11<00:00, 11.40s/ file]
# Dl Size...: 100% 11/11 [00:11<00:00,  1.04s/ MiB]
# Dl Completed...: 100% 1/1 [00:11<00:00, 11.40s/ url]
# Generating splits...:   0% 0/2 [00:00<?, ? splits/s]
# Generating train examples...:   0% 0/120000 [00:00<?, ? examples/s]
# Generating train examples...:   1% 825/120000 [00:00<00:14, 8245.37 examples/s]
# Generating train examples...:   1% 1661/120000 [00:00<00:14, 8285.44 examples/s]
# Generating train examples...:   2% 2490/120000 [00:00<00:14, 8102.23 examples/s]
# Generating train examples...:   3% 3301/120000 [00:00<00:14, 7834.55 examples/s]
# Generating train examples...:   3% 4144/120000 [00:00<00:14, 8039.73 examples/s]
# Generating train examples...:   4% 4950/120000 [00:00<00:14, 7991.66 examples/s]
# Generating train examples...:   5% 5799/120000 [00:00<00:14, 8151.07 examples/s]
# Generating train examples...:   6% 6653/120000 [00:00<00:13, 8271.33 examples/s]
# Generating train examples...:   6% 7481/120000 [00:00<00:13, 8227.69 examples/s]
# Generating train examples...:   7% 8331/120000 [00:01<00:13, 8307.97 examples/s]
# Generating train examples...:   8% 9171/120000 [00:01<00:13, 8334.90 examples/s]
# Generating train examples...:   8% 10005/120000 [00:01<00:13, 8258.66 examples/s]
# Generating train examples...:   9% 10854/120000 [00:01<00:13, 8326.81 examples/s]
# Generating train examples...:  10% 11687/120000 [00:01<00:13, 8159.02 examples/s]
# Generating train examples...:  10% 12518/120000 [00:01<00:13, 8202.55 examples/s]
# Generating train examples...:  11% 13358/120000 [00:01<00:12, 8258.23 examples/s]
# Generating train examples...:  12% 14213/120000 [00:01<00:12, 8342.71 examples/s]
# Generating train examples...:  13% 15050/120000 [00:01<00:12, 8350.45 examples/s]
# Generating train examples...:  13% 15915/120000 [00:01<00:12, 8437.45 examples/s]
# Generating train examples...:  14% 16760/120000 [00:02<00:12, 8270.25 examples/s]
# Generating train examples...:  15% 17599/120000 [00:02<00:12, 8303.71 examples/s]
# Generating train examples...:  15% 18477/120000 [00:02<00:12, 8441.58 examples/s]
# Generating train examples...:  16% 19322/120000 [00:02<00:12, 8249.61 examples/s]
# Generating train examples...:  17% 20149/120000 [00:02<00:12, 7924.02 examples/s]
# Generating train examples...:  17% 20945/120000 [00:02<00:12, 7926.18 examples/s]
# Generating train examples...:  18% 21777/120000 [00:02<00:12, 8040.18 examples/s]
# Generating train examples...:  19% 22636/120000 [00:02<00:11, 8200.24 examples/s]
# Generating train examples...:  20% 23462/120000 [00:02<00:11, 8217.70 examples/s]
# Generating train examples...:  20% 24298/120000 [00:02<00:11, 8255.74 examples/s]
# Generating train examples...:  21% 25125/120000 [00:03<00:11, 8158.98 examples/s]
# Generating train examples...:  22% 25942/120000 [00:03<00:11, 7845.94 examples/s]
# Generating train examples...:  22% 26786/120000 [00:03<00:11, 8014.89 examples/s]
# Generating train examples...:  23% 27591/120000 [00:03<00:11, 7785.50 examples/s]
# Generating train examples...:  24% 28373/120000 [00:03<00:11, 7689.83 examples/s]
# Generating train examples...:  24% 29229/120000 [00:03<00:11, 7939.99 examples/s]
# Generating train examples...:  25% 30057/120000 [00:03<00:11, 8037.37 examples/s]
# Generating train examples...:  26% 30888/120000 [00:03<00:10, 8117.22 examples/s]
# Generating train examples...:  26% 31753/120000 [00:03<00:10, 8273.92 examples/s]
# Generating train examples...:  27% 32583/120000 [00:03<00:10, 8278.00 examples/s]
# Generating train examples...:  28% 33412/120000 [00:04<00:10, 8267.33 examples/s]
# Generating train examples...:  29% 34240/120000 [00:04<00:10, 8197.35 examples/s]
# Generating train examples...:  29% 35068/120000 [00:04<00:10, 8221.40 examples/s]
# Generating train examples...:  30% 35891/120000 [00:04<00:10, 8161.75 examples/s]
# Generating train examples...:  31% 36708/120000 [00:04<00:10, 7867.23 examples/s]
# Generating train examples...:  31% 37498/120000 [00:04<00:10, 7720.38 examples/s]
# Generating train examples...:  32% 38272/120000 [00:04<00:10, 7675.31 examples/s]
# Generating train examples...:  33% 39054/120000 [00:04<00:10, 7712.83 examples/s]
# Generating train examples...:  33% 39827/120000 [00:04<00:10, 7597.69 examples/s]
# Generating train examples...:  34% 40664/120000 [00:05<00:10, 7821.53 examples/s]
# Generating train examples...:  35% 41535/120000 [00:05<00:09, 8082.81 examples/s]
# Generating train examples...:  35% 42372/120000 [00:05<00:09, 8166.96 examples/s]
# Generating train examples...:  36% 43232/120000 [00:05<00:09, 8295.20 examples/s]
# Generating train examples...:  37% 44093/120000 [00:05<00:09, 8387.21 examples/s]
# Generating train examples...:  37% 44933/120000 [00:05<00:09, 8158.71 examples/s]
# Generating train examples...:  38% 45812/120000 [00:05<00:08, 8340.78 examples/s]
# Generating train examples...:  39% 46648/120000 [00:05<00:09, 8095.77 examples/s]
# Generating train examples...:  40% 47460/120000 [00:05<00:08, 8061.81 examples/s]
# Generating train examples...:  40% 48268/120000 [00:05<00:08, 8034.25 examples/s]
# Generating train examples...:  41% 49116/120000 [00:06<00:08, 8163.50 examples/s]
# Generating train examples...:  42% 49934/120000 [00:06<00:08, 8133.32 examples/s]
# Generating train examples...:  42% 50790/120000 [00:06<00:08, 8256.85 examples/s]
# Generating train examples...:  43% 51648/120000 [00:06<00:08, 8352.26 examples/s]
# Generating train examples...:  44% 52484/120000 [00:06<00:08, 8157.00 examples/s]
# Generating train examples...:  44% 53301/120000 [00:06<00:08, 8055.80 examples/s]
# Generating train examples...:  45% 54114/120000 [00:06<00:08, 8076.93 examples/s]
# Generating train examples...:  46% 54927/120000 [00:06<00:08, 8091.78 examples/s]
# Generating train examples...:  46% 55794/120000 [00:06<00:07, 8262.78 examples/s]
# Generating train examples...:  47% 56621/120000 [00:06<00:07, 8096.44 examples/s]
# Generating train examples...:  48% 57491/120000 [00:07<00:07, 8272.91 examples/s]
# Generating train examples...:  49% 58330/120000 [00:07<00:07, 8306.12 examples/s]
# Generating train examples...:  49% 59162/120000 [00:07<00:07, 8266.27 examples/s]
# Generating train examples...:  50% 60027/120000 [00:07<00:07, 8379.00 examples/s]
# Generating train examples...:  51% 60892/120000 [00:07<00:06, 8459.42 examples/s]
# Generating train examples...:  51% 61739/120000 [00:07<00:07, 8154.77 examples/s]
# Generating train examples...:  52% 62568/120000 [00:07<00:07, 8193.25 examples/s]
# Generating train examples...:  53% 63437/120000 [00:07<00:06, 8338.89 examples/s]
# Generating train examples...:  54% 64273/120000 [00:07<00:06, 8252.83 examples/s]
# Generating train examples...:  54% 65129/120000 [00:07<00:06, 8342.42 examples/s]
# Generating train examples...:  55% 65965/120000 [00:08<00:06, 8331.27 examples/s]
# Generating train examples...:  56% 66799/120000 [00:08<00:06, 8241.35 examples/s]
# Generating train examples...:  56% 67638/120000 [00:08<00:06, 8283.21 examples/s]
# Generating train examples...:  57% 68467/120000 [00:08<00:06, 8206.63 examples/s]
# Generating train examples...:  58% 69289/120000 [00:08<00:06, 8178.53 examples/s]
# Generating train examples...:  58% 70108/120000 [00:08<00:06, 8068.77 examples/s]
# Generating train examples...:  59% 70959/120000 [00:08<00:05, 8196.88 examples/s]
# Generating train examples...:  60% 71780/120000 [00:08<00:05, 8066.95 examples/s]
# Generating train examples...:  60% 72593/120000 [00:08<00:05, 8082.82 examples/s]
# Generating train examples...:  61% 73409/120000 [00:09<00:05, 8103.83 examples/s]
# Generating train examples...:  62% 74220/120000 [00:09<00:05, 7741.61 examples/s]
# Generating train examples...:  63% 75058/120000 [00:09<00:05, 7923.30 examples/s]
# Generating train examples...:  63% 75890/120000 [00:09<00:05, 8037.20 examples/s]
# Generating train examples...:  64% 76697/120000 [00:09<00:05, 8035.75 examples/s]
# Generating train examples...:  65% 77575/120000 [00:09<00:05, 8255.27 examples/s]
# Generating train examples...:  65% 78403/120000 [00:09<00:05, 8045.80 examples/s]
# Generating train examples...:  66% 79210/120000 [00:09<00:05, 7988.26 examples/s]
# Generating train examples...:  67% 80045/120000 [00:09<00:04, 8090.87 examples/s]
# Generating train examples...:  67% 80890/120000 [00:09<00:04, 8195.05 examples/s]
# Generating train examples...:  68% 81711/120000 [00:10<00:04, 8019.15 examples/s]
# Generating train examples...:  69% 82572/120000 [00:10<00:04, 8191.87 examples/s]
# Generating train examples...:  69% 83393/120000 [00:10<00:04, 7675.98 examples/s]
# Generating train examples...:  70% 84195/120000 [00:10<00:04, 7771.48 examples/s]
# Generating train examples...:  71% 85025/120000 [00:10<00:04, 7921.95 examples/s]
# Generating train examples...:  72% 85822/120000 [00:10<00:04, 7874.25 examples/s]
# Generating train examples...:  72% 86613/120000 [00:10<00:04, 7860.53 examples/s]
# Generating train examples...:  73% 87445/120000 [00:10<00:04, 7993.27 examples/s]
# Generating train examples...:  74% 88282/120000 [00:10<00:03, 8103.55 examples/s]
# Generating train examples...:  74% 89138/120000 [00:10<00:03, 8238.11 examples/s]
# Generating train examples...:  75% 89963/120000 [00:11<00:03, 8208.77 examples/s]
# Generating train examples...:  76% 90785/120000 [00:11<00:03, 8187.14 examples/s]
# Generating train examples...:  76% 91631/120000 [00:11<00:03, 8266.33 examples/s]
# Generating train examples...:  77% 92498/120000 [00:11<00:03, 8385.68 examples/s]
# Generating train examples...:  78% 93337/120000 [00:11<00:03, 8197.12 examples/s]
# Generating train examples...:  79% 94223/120000 [00:11<00:03, 8391.49 examples/s]
# Generating train examples...:  79% 95064/120000 [00:11<00:03, 8253.59 examples/s]
# Generating train examples...:  80% 95891/120000 [00:11<00:02, 8217.46 examples/s]
# Generating train examples...:  81% 96773/120000 [00:11<00:02, 8394.69 examples/s]
# Generating train examples...:  81% 97642/120000 [00:11<00:02, 8480.38 examples/s]
# Generating train examples...:  82% 98491/120000 [00:12<00:02, 8368.04 examples/s]
# Generating train examples...:  83% 99345/120000 [00:12<00:02, 8415.90 examples/s]
# Generating train examples...:  83% 100188/120000 [00:12<00:02, 8332.49 examples/s]
# Generating train examples...:  84% 101022/120000 [00:12<00:02, 8230.85 examples/s]
# Generating train examples...:  85% 101899/120000 [00:12<00:02, 8387.89 examples/s]
# Generating train examples...:  86% 102739/120000 [00:12<00:02, 8381.30 examples/s]
# Generating train examples...:  86% 103578/120000 [00:12<00:02, 8013.35 examples/s]
# Generating train examples...:  87% 104450/120000 [00:12<00:01, 8214.54 examples/s]
# Generating train examples...:  88% 105291/120000 [00:12<00:01, 8269.76 examples/s]
# Generating train examples...:  88% 106121/120000 [00:13<00:01, 8220.50 examples/s]
# Generating train examples...:  89% 106988/120000 [00:13<00:01, 8350.38 examples/s]
# Generating train examples...:  90% 107825/120000 [00:13<00:01, 8325.92 examples/s]
# Generating train examples...:  91% 108659/120000 [00:13<00:01, 8295.85 examples/s]
# Generating train examples...:  91% 109506/120000 [00:13<00:01, 8345.38 examples/s]
# Generating train examples...:  92% 110389/120000 [00:13<00:01, 8488.72 examples/s]
# Generating train examples...:  93% 111239/120000 [00:13<00:01, 8273.34 examples/s]
# Generating train examples...:  93% 112068/120000 [00:13<00:00, 8158.24 examples/s]
# Generating train examples...:  94% 112930/120000 [00:13<00:00, 8290.90 examples/s]
# Generating train examples...:  95% 113761/120000 [00:13<00:00, 8220.37 examples/s]
# Generating train examples...:  96% 114615/120000 [00:14<00:00, 8313.51 examples/s]
# Generating train examples...:  96% 115452/120000 [00:14<00:00, 8329.52 examples/s]
# Generating train examples...:  97% 116286/120000 [00:14<00:00, 8182.87 examples/s]
# Generating train examples...:  98% 117131/120000 [00:14<00:00, 8259.91 examples/s]
# Generating train examples...:  98% 117958/120000 [00:14<00:00, 8257.47 examples/s]
# Generating train examples...:  99% 118785/120000 [00:14<00:00, 8181.75 examples/s]
# Generating train examples...: 100% 119660/120000 [00:14<00:00, 8349.46 examples/s]
#
# Shuffling /root/tensorflow_datasets/ag_news_subset/1.0.0.incompleteEMLH3T/ag_news_subset-train.tfrecord*...:   0% 0/120000 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/ag_news_subset/1.0.0.incompleteEMLH3T/ag_news_subset-train.tfrecord*...:   0% 1/120000 [00:00<5:13:30,  6.38 examples/s]
# Shuffling /root/tensorflow_datasets/ag_news_subset/1.0.0.incompleteEMLH3T/ag_news_subset-train.tfrecord*...:  34% 41060/120000 [00:00<00:00, 195769.41 examples/s]
# Shuffling /root/tensorflow_datasets/ag_news_subset/1.0.0.incompleteEMLH3T/ag_news_subset-train.tfrecord*...:  67% 80962/120000 [00:00<00:00, 278110.72 examples/s]
# Shuffling /root/tensorflow_datasets/ag_news_subset/1.0.0.incompleteEMLH3T/ag_news_subset-train.tfrecord*...:  96% 115221/120000 [00:00<00:00, 301742.48 examples/s]
# INFO[writer.py]: Done writing /root/tensorflow_datasets/ag_news_subset/1.0.0.incompleteEMLH3T/ag_news_subset-train.tfrecord*. Number of examples: 120000 (shards: [120000])
# Generating splits...:  50% 1/2 [00:15<00:15, 15.20s/ splits]
# Generating test examples...:   0% 0/7600 [00:00<?, ? examples/s]
# Generating test examples...:  11% 840/7600 [00:00<00:00, 8395.86 examples/s]
# Generating test examples...:  22% 1680/7600 [00:00<00:00, 8135.29 examples/s]
# Generating test examples...:  34% 2554/7600 [00:00<00:00, 8404.22 examples/s]
# Generating test examples...:  45% 3429/7600 [00:00<00:00, 8535.17 examples/s]
# Generating test examples...:  56% 4284/7600 [00:00<00:00, 8127.04 examples/s]
# Generating test examples...:  68% 5172/7600 [00:00<00:00, 8372.02 examples/s]
# Generating test examples...:  79% 6020/7600 [00:00<00:00, 8405.84 examples/s]
# Generating test examples...:  90% 6863/7600 [00:00<00:00, 8254.32 examples/s]
#
# Shuffling /root/tensorflow_datasets/ag_news_subset/1.0.0.incompleteEMLH3T/ag_news_subset-test.tfrecord*...:   0% 0/7600 [00:00<?, ? examples/s]
# INFO[writer.py]: Done writing /root/tensorflow_datasets/ag_news_subset/1.0.0.incompleteEMLH3T/ag_news_subset-test.tfrecord*. Number of examples: 7600 (shards: [7600])
# Dataset ag_news_subset downloaded and prepared to /root/tensorflow_datasets/ag_news_subset/1.0.0. Subsequent calls will reuse this data.
# INFO[build.py]: Dataset generation complete...
#
# tfds.core.DatasetInfo(
#     name='ag_news_subset',
#     full_name='ag_news_subset/1.0.0',
#     description="""
#     AG is a collection of more than 1 million news articles.
#     News articles have been gathered from more than 2000  news sources by ComeToMyHead in more than 1 year of activity.
#     ComeToMyHead is an academic news search engine which has been running since July, 2004.
#     The dataset is provided by the academic comunity for research purposes in data mining (clustering, classification, etc),
#     information retrieval (ranking, search, etc), xml, data compression, data streaming,
#     and any other non-commercial activity.
#     For more information, please refer to the link http://www.di.unipi.it/~gulli/AG_corpus_of_news_articles.html .
#
#     The AG's news topic classification dataset is constructed by Xiang Zhang (xiang.zhang@nyu.edu) from the dataset above.
#     It is used as a text classification benchmark in the following paper:
#     Xiang Zhang, Junbo Zhao, Yann LeCun. Character-level Convolutional Networks for Text Classification. Advances in Neural Information Processing Systems 28 (NIPS 2015).
#
#     The AG's news topic classification dataset is constructed by choosing 4 largest classes from the original corpus.
#     Each class contains 30,000 training samples and 1,900 testing samples.
#     The total number of training samples is 120,000 and testing 7,600.
#     """,
#     homepage='https://arxiv.org/abs/1509.01626',
#     data_path='/root/tensorflow_datasets/ag_news_subset/1.0.0',
#     file_format=tfrecord,
#     download_size=11.24 MiB,
#     dataset_size=35.79 MiB,
#     features=FeaturesDict({
#         'description': Text(shape=(), dtype=tf.string),
#         'label': ClassLabel(shape=(), dtype=tf.int64, num_classes=4),
#         'title': Text(shape=(), dtype=tf.string),
#     }),
#     supervised_keys=('description', 'label'),
#     disable_shuffling=False,
#     splits={
#         'test': <SplitInfo num_examples=7600, num_shards=1>,
#         'train': <SplitInfo num_examples=120000, num_shards=1>,
#     },
#     citation="""@misc{zhang2015characterlevel,
#         title={Character-level Convolutional Networks for Text Classification},
#         author={Xiang Zhang and Junbo Zhao and Yann LeCun},
#         year={2015},
#         eprint={1509.01626},
#         archivePrefix={arXiv},
#         primaryClass={cs.LG}
#     }""",
# )

# %% [markdown]
# ### Deep learning for text

# %% [markdown]
# #### Natural-language processing: The bird's eye view

# %% [markdown]
# Handcrafted rules held out as the dominant approach well into the 1990s. But starting in the late 1980s, faster computers and greater data availability started making a better alternative viable.

# %% [markdown]
# We started seeing machine learning approaches to natural language processing. The earliest ones were based on `decision trees`—the intent was literally to automate the development of the kind of if/then/else rules of previous systems

# %% [markdown]
# Then statistical approaches started gaining speed, starting with `logistic regression`. Over time, learned parametric models fully took over, and linguistics came to be seen as more of a hindrance than a useful tool.

# %% [markdown]
# In early 2015, Keras made available the first open source, easy-to-use implementation of `LSTM`, just at the start of a massive wave of renewed interest in recurrent neural networks—until then, there had only been “research code” that couldn’t be readily reused.

# %% [markdown]
# Then from 2015 to 2017, recurrent neural networks dominated the booming NLP scene. `Bidirectional LSTM` models, in particular, set the state of the art on many important tasks, from summarization to question-answering to machine translation.

# %% [markdown]
# Finally, around 2017–2018, a new architecture rose to replace RNNs: the `Transformer`. Transformers unlocked considerable progress across the field in a short period of time, and today most NLP systems are based on them.

# %% [markdown]
# ### Common Natural Language Processing Tasks
#
# The applications of natural language algorithms are commonly called tasks. Here are some popular tasks:
#
# 1. **Sentiment Analysis**: Given opinionated text like a movie review, determine whether the overall sense is positive or negative.
# 2. **Translation**: Turn text into another language.
# Answer Questions: Answer questions about the text, like who is the hero, or what actions occurred.
# 3. **Summarize or Paraphrase**: Provide a short overview of the text, emphasizing the main points.
# 4. **Generate New Text**: Given some starting text, write more text that seems to follow from it.
# 5. **Logical Flow**: If a sentence first asserts a premise and the following sentence asserts a conclusion based on that premise, determine whether the conclusion logically follows from the premise.

# %% [markdown]
# ### Preparing text data

# %% [markdown]
# <img src="https://github.com/djp840/MSDS_458_Public/blob/master/images/11-01.png?raw=1">

# %% [markdown]
# #### Text standardization

# %% [markdown]
# Text standardization is a basic form of feature engineering that aims to erase encoding differences that you don’t want your model to have to deal with. It’s not exclusive to machine learning, either—you’d have to do the same thing if you were building a search engine.

# %% [markdown]
# One of the simplest and most widespread standardization schemes is “convert to lowercase and remove punctuation characters.”

# %% [markdown]
# With these standardization techniques, your model will require less training data and will generalize better—it won’t need abundant examples of both “Sunset” and “sunset” to learn that they mean the same thing...

# %% [markdown]
# #### Text splitting (tokenization)

# %% [markdown]
# Once your text is standardized, you need to break it up into units to be vectorized (tokens), a step called tokenization. You could do this in three different ways:
#
# * `Word-level tokenization`—Where tokens are space-separated (or punctuation-separated) substrings. A variant of this is to further split words into subwords when applicable—for instance, treating “staring” as “star+ing” or “called” as “call+ed.”
# * `N-gram tokenization`—Where tokens are groups of N consecutive words. For instance, “the cat” or “he was” would be 2-gram tokens (also called bigrams).
# * `Character-level tokenization`—Where each character is its own token. In practice, this scheme is rarely used, and you only really see it in specialized contexts, like text generation or speech recognition.

# %% [markdown]
# Here’s a simple example. Consider the sentence “the cat sat on the mat.” It may be decomposed into the following set of 2-grams:
#
# `{"the", "the cat", "cat", "cat sat", "sat",
#  "sat on", "on", "on the", "the mat", "mat"}`

# %% [markdown]
# It may also be decomposed into the following set of 3-grams:
#
# `{"the", "the cat", "cat", "cat sat", "the cat sat",
#  "sat", "sat on", "on", "cat sat on", "on the",
#  "sat on the", "the mat", "mat", "on the mat"}`

# %% [markdown]
# `One-dimensional convnets`, `recurrent neural networks`, and `Transformers` are capable of learning representations for groups of words and characters without being explicitly told about the existence of such groups, by looking at continuous word or character sequences.

# %% [markdown]
# #### Vocabulary indexing

# %% [markdown]
# 1. Build an index of all terms found in the training data (the “vocabulary”), and assign a unique integer to each entry in the vocabulary.
# ```python
# vocabulary = {}
# for text in dataset:
#     text = standardize(text)
#     tokens = tokenize(text)
#     for token in tokens:
#         if token not in vocabulary:
#             vocabulary[token] = len(vocabulary)
# ```

# %% [markdown]
# 2. You can then convert that integer into a vector encoding that can be processed by a neural network, like a one-hot vector:
# ```python
# def one_hot_encode_token(token):
#     vector = np.zeros((len(vocabulary),))
#     token_index = vocabulary[token]
#     vector[token_index] = 1
#     return vector
# ```

# %% [markdown]
# #### Using the TextVectorization layer

# %% [markdown]
# ```python
# import string
#
# class Vectorizer:
#     def standardize(self, text):
#         text = text.lower()
#         return "".join(char for char in text
#                        if char not in string.punctuation)
#
#     def tokenize(self, text):
#         text = self.standardize(text)
#         return text.split()
#
#     def make_vocabulary(self, dataset):
#         self.vocabulary = {"": 0, "[UNK]": 1}
#         for text in dataset:
#             text = self.standardize(text)
#             tokens = self.tokenize(text)
#             for token in tokens:
#                 if token not in self.vocabulary:
#                     self.vocabulary[token] = len(self.vocabulary)
#         self.inverse_vocabulary = dict(
#             (v, k) for k, v in self.vocabulary.items())
#
#     def encode(self, text):
#         text = self.standardize(text)
#         tokens = self.tokenize(text)
#         return [self.vocabulary.get(token, 1) for token in tokens]
#
#     def decode(self, int_sequence):
#         return " ".join(
#             self.inverse_vocabulary.get(i, "[UNK]") for i in int_sequence)
#
# vectorizer = Vectorizer()
# # Haiku by poet Hokushi
# dataset = [
#     "I write, erase, rewrite",
#     "Erase again, and then",
#     "A poppy blooms.",
# ]
# vectorizer.make_vocabulary(dataset)
# ```

# %% [markdown]
# ```python
# >>> test_sentence = "I write, rewrite, and still rewrite again"
# >>> encoded_sentence = vectorizer.encode(test_sentence)
# >>> print(encoded_sentence)
# [2, 3, 5, 7, 1, 5, 6]
# >>> decoded_sentence = vectorizer.decode(encoded_sentence)
# >>> print(decoded_sentence)
# "i write rewrite and [UNK] rewrite again"
# ```

# %% [markdown]
# However, using something like this wouldn’t be very performant. In practice, you’ll work with the Keras `TextVectorization` layer, which is fast and efficient and can be dropped directly into a `tf.data` pipeline or a Keras model.

# %% [markdown]
# ```python
# from tensorflow.keras.layers import TextVectorization
# text_vectorization = TextVectorization(
#     output_mode="int",    # Configures the layer to return sequences of words encoded as integer indices.
# )

# %% [markdown]
# By default, the `TextVectorization` layer will use the setting “convert to lowercase and remove punctuation” for text standardization, and “split on whitespace” for tokenization.

# %% [markdown]
# ```python
# import re
# import string
# import tensorflow as tf
#
# def custom_standardization_fn(string_tensor):
#     lowercase_string = tf.strings.lower(string_tensor)              ❶
#     return tf.strings.regex_replace(                                ❷
#         lowercase_string, f"[{re.escape(string.punctuation)}]", "")
#
# def custom_split_fn(string_tensor):
#     return tf.strings.split(string_tensor)                          ❸
#
# text_vectorization = TextVectorization(
#     output_mode="int",
#     standardize=custom_standardization_fn,
#     split=custom_split_fn,
# )
# ```

# %% [markdown]
# ❶ Convert strings to lowercase.
#
# ❷ Replace punctuation characters with the empty string.
#
# ❸ Split strings on whitespace.

# %% [markdown]
# To index the vocabulary of a text corpus, just call the `adapt()` method of the layer with a `Dataset` object that yields strings, or just with a list of Python strings:
# ```python
# dataset = [
#     "I write, erase, rewrite",
#     "Erase again, and then",
#     "A poppy blooms.",
# ]
# text_vectorization.adapt(dataset)
# ```

# %% [markdown]
# Note that you can retrieve the computed vocabulary via `get_vocabulary()`
# ```python
# >>> text_vectorization.get_vocabulary()
# ["", "[UNK]", "erase", "write", ...]
# ```

# %% [markdown]
# This method can be useful if you need to convert text encoded as integer sequences back into words. The first two entries in the vocabulary are the `mask` token (index 0) and the `OOV` token (index 1).
#
# Entries in the vocabulary list are sorted by frequency, so with a real-world dataset, very common words like “the” or “a” would come first.

# %% [markdown]
# #### Two ways we could use our `TextVectorization` layer

# %% [markdown]
# #####  The first option is to put it in the `tf.data pipeline`, like this:

# %% [markdown]
# There are two ways we could use our TextVectorization layer. The first option is to put it in the `tf.data pipeline`, like this:
# ```python
# int_sequence_dataset = string_dataset.map(   ❶
#     text_vectorization,
#     num_parallel_calls=4)                    ❷
# ```

# %% [markdown]
# ❶ string_dataset would be a dataset that yields string tensors.
#
# ❷ The num_parallel_calls argument is used to parallelize the map() call across multiple CPU cores.

# %% [markdown]
# ##### The second option is to make it part of the `model` (after all, it’s a Keras layer), like this:

# %% [markdown]
# The second option is to make it part of the model (after all, it’s a Keras layer), like this:
# ```python
# text_input = keras.Input(shape=(), dtype="string")             ❶
# vectorized_text = text_vectorization(text_input)               ❷
# embedded_input = keras.layers.Embedding(...)(vectorized_text)  ❸
# output = ...                                                   ❸
# model = keras.Model(text_input, output)
# ```
# ❶ Create a symbolic input that expects strings.
#
# ❷ Apply the text vectorization layer to it.
#
# ❸ You can keep chaining new layers on top—just your regular Functional API model.

# %% [markdown]
# ***There’s an important difference between the two**: if the vectorization step is part of the model, it will happen synchronously with the rest of the model. This means that at each training step, the rest of the model (placed on the GPU) will have to wait for the output of the TextVectorization layer (placed on the CPU) to be ready in order to get to work.

# %% [markdown]
# Meanwhile, putting the layer in the `tf.data` pipeline enables you to do asynchronous preprocessing of your data on CPU: while the GPU runs the model on one batch of vectorized data, the CPU stays busy by vectorizing the next batch of raw strings.

# %% [markdown]
# So if you’re training the model on GPU or TPU, you’ll probably want to go with the first option to get the best performance.

# %% [markdown]
# Now, if you were to export our model to a production environment, you would want to ship a model that accepts raw strings as input—otherwise you would have to reimplement text standardization and tokenization in your production environment (maybe in JavaScript?), and you would face the risk of introducing small preprocessing discrepancies that would hurt the model’s accuracy. Thankfully, the TextVectorization layer enables you to include text preprocessing right into your model, making it easier to deploy.

# %% [markdown]
# #### Exporting a model that processes raw strings

# %% [markdown]
# ```python
# inputs = keras.Input(shape=(1,), dtype="string")   ❶
# processed_inputs = text_vectorization(inputs)      ❷
# outputs = model(processed_inputs)                  ❸
# inference_model = keras.Model(inputs, outputs)     ❹
# ```

# %% [markdown]
# ❶ One input sample would be one string.
#
# ❷ Apply text preprocessing.
#
# ❸ Apply the previously trained model.
#
# ❹ Instantiate the end-to-end model.

# %% [markdown]
# The resulting model can process batches of `raw strings`:
# ```python
# import tensorflow as tf
# raw_text_data = tf.convert_to_tensor([
#     ["That was an excellent movie, I loved it."],
# ])
# predictions = inference_model(raw_text_data)
# print(f"{float(predictions[0] * 100):.2f} percent positive")
# ```

# %% [markdown]
# #### Verify TensorFlow Version and Keras Version

# %%
print("This notebook requires TensorFlow 2.0 or above")
print("TensorFlow version: ", tf.__version__)
assert version.parse(tf.__version__).release[0] >=2
# Out:
# This notebook requires TensorFlow 2.0 or above
# TensorFlow version:  2.9.2

# %%
print("Keras version: ", keras.__version__)
# Out:
# Keras version:  2.9.0

# %% [markdown]
# #### Mount Google Drive to Colab Environment

# %%
#from google.colab import drive
#drive.mount('/content/gdrive')

# %% [markdown]
# #### Visualization Utility Functions

# %%
def print_validation_report(test_labels, predictions):
    print("Classification Report")
    print(classification_report(test_labels, predictions))
    print('Accuracy Score: {}'.format(accuracy_score(test_labels, predictions)))
    print('Root Mean Square Error: {}'.format(np.sqrt(MSE(test_labels, predictions)))) 
    
def plot_confusion_matrix(y_true, y_pred):
    mtx = confusion_matrix(y_true, y_pred)
    fig, ax = plt.subplots(figsize=(8,8))
    sns.heatmap(mtx, annot=True, fmt='d', linewidths=.75,  cbar=False, ax=ax,cmap='Blues',linecolor='white')
    #  square=True,
    plt.ylabel('true label')
    plt.xlabel('predicted label')

def plot_graphs(history, metric):
  plt.plot(history.history[metric])
  plt.plot(history.history['val_'+metric], '')
  plt.xlabel("Epochs")
  plt.ylabel(metric)
  plt.legend([metric, 'val_'+metric])

# %% [markdown]
# #### Vectorization Class

# %%
class Vectorizer:
    def standardize(self, text):
        text = text.lower()
        return "".join(char for char in text if char not in string.punctuation)

    def tokenize(self, text):
        text = self.standardize(text)
        return text.split()

    def make_vocabulary(self, dataset):
        self.vocabulary = {"": 0, "[UNK]": 1}
        for text in dataset:
            text = self.standardize(text)
            tokens = self.tokenize(text)
            for token in tokens:
                if token not in self.vocabulary:
                    self.vocabulary[token] = len(self.vocabulary)
        self.inverse_vocabulary = dict(
            (v, k) for k, v in self.vocabulary.items())

    def encode(self, text):
        text = self.standardize(text)
        tokens = self.tokenize(text)
        return [self.vocabulary.get(token, 1) for token in tokens]

    def decode(self, int_sequence):
        return " ".join(
            self.inverse_vocabulary.get(i, "[UNK]") for i in int_sequence)

# %% [markdown]
# ### Display The Number of Batches

# %%
len(train_ds), len(val_ds), len(test_ds)
# Out:
# (3563, 188, 238)

# %% [markdown]
# ### Displaying The Shapes and Dtypes of the First Batch

# %% [raw]
# 'description': Text(shape=(), dtype=tf.string),
# 'label': ClassLabel(shape=(), dtype=tf.int64, num_classes=4),
# 'title': Text(shape=(), dtype=tf.string),

# %%
for inputs, targets in train_ds:
    print("inputs.shape:", inputs.shape)
    print()
    print("inputs.dtype:", inputs.dtype)
    print()
    print("targets.shape:", targets.shape)
    print()
    print("targets.dtype:", targets.dtype)
    print()
    print("inputs[0]:", inputs[0])
    print()
    print("targets[0]:", targets[0])
    break
# Out:
# inputs.shape: (32,)
#
# inputs.dtype: <dtype: 'string'>
#
# targets.shape: (32,)
#
# targets.dtype: <dtype: 'int64'>
#
# inputs[0]: tf.Tensor(b'AMD #39;s new dual-core Opteron chip is designed mainly for corporate computing applications, including databases, Web services, and financial transactions.', shape=(), dtype=string)
#
# targets[0]: tf.Tensor(3, shape=(), dtype=int64)

# %% [markdown]
# ### Stop words and Text vectorization

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <b>tf.keras.layers.TextVectorization</b><br>
#     https://www.tensorflow.org/api_docs/python/tf/keras/layers/TextVectorization
#     </div>

# %%
def custom_stopwords(input_text):
    lowercase = tf.strings.lower(input_text)
    stripped_punct = tf.strings.regex_replace(lowercase
                                  ,'[%s]' % re.escape(string.punctuation)
                                  ,'')
    return tf.strings.regex_replace(stripped_punct, r'\b(' + r'|'.join(STOPWORDS) + r')\b\s*',"")

# %%
nltk.download('stopwords')
STOPWORDS = stopwords.words("english")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
text_only_train_ds = train_ds.map(lambda x, y: x)

# %%
# Text Vectorizer

max_length = 150
max_tokens = 1000
text_vectorization = layers.TextVectorization(
    max_tokens=max_tokens,
    output_mode="int",
   # output_sequence_length=max_length,
    standardize=custom_stopwords
)
text_vectorization.adapt(text_only_train_ds)

int_train_ds = train_ds.map(
    lambda x, y: (text_vectorization(x), y),
    num_parallel_calls=4)
int_val_ds = val_ds.map(
    lambda x, y: (text_vectorization(x), y),
    num_parallel_calls=4)
int_test_ds = test_ds.map(
    lambda x, y: (text_vectorization(x), y),
    num_parallel_calls=4)

# %%
# %%time
# max_length = 150
# max_tokens = 1000
# encoder_1000 = layers.TextVectorization(
#     max_tokens=max_tokens,
#     output_mode="int",
#     output_sequence_length=max_length,
#     standardize=custom_stopwords # removing stop words
# )
# encoder_100.adapt(text_only_train_ds)

# int_train_ds = train_ds.map(
#     lambda x, y: (text_vectorization(x), y),
#     num_parallel_calls=4)
# int_val_ds = val_ds.map(
#     lambda x, y: (text_vectorization(x), y),
#     num_parallel_calls=4)
# int_test_ds = test_ds.map(
#     lambda x, y: (text_vectorization(x), y),
#     num_parallel_calls=4)
# vocab_1000 = np.array(encoder_1000.get_vocabulary());

# %%
# %%time
# encoder_1000 = TextVectorization(
#     max_tokens=1000,
#     output_mode="multi_hot")
#    # standardize=custom_stopwords) # removing stop words

# %%
# text_only_train_ds = train_ds.map(lambda x, y: x)

# %%
# for text in text_only_train_ds:
#     print(f"Get first batch of {text.shape[0]} news articles.\n")
#     print(f"Here is the first news article:\n\n{text[0]}.")
#     break

# %%
# %%time
# encoder = tf.keras.layers.experimental.preprocessing.TextVectorization(
#     max_tokens=1000,
#     output_sequence_length=150
#     standardize=custom_stopwords)
# encoder.adapt(train_ds.map(lambda text, label: text))

# %% [markdown]
# # Experiment B - RNN

# %% [markdown]
# ## RNN_Model1
#
# Bidirectional, No Regularization, Default output sequnece layer

# %% [markdown]
# ### Making the Model

# %%
# Define the model

RNN_model1 = tf.keras.Sequential([
                           #  text_vectorization
                              tf.keras.layers.Embedding(input_dim=len(text_vectorization.get_vocabulary())
                              ,output_dim=32
                              ,mask_zero=True)
                              ,tf.keras.layers.Bidirectional(tf.keras.layers.SimpleRNN(32)) # Bidirectional
                              ,tf.keras.layers.Dense(32, activation='relu')
                              ,tf.keras.layers.Dense(4,activation='softmax') # 4 classes: World, Sports, Business, Sci.Tech
                          #    ,kernel_regularizer=tf.keras.regularizers.L2(0.001) # Without Regularization
])

# %%
# compile the model

RNN_model1.compile(optimizer='adam'
              ,loss=tf.keras.losses.SparseCategoricalCrossentropy()
              ,metrics=['accuracy'])

# %%
# Fit the model

start_time = dt.now()
history = RNN_model1.fit(int_train_ds
                    ,epochs=200
                    ,validation_data=int_val_ds
                    ,validation_steps=10
                    ,callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=1)]
                    )
end_time = dt.now()
print(f'RNN_model4 fit time: {end_time-start_time}')
# Out:
# Epoch 1/200
# 3563/3563 [==============================] - 92s 25ms/step - loss: 0.4937 - accuracy: 0.8184 - val_loss: 0.4207 - val_accuracy: 0.8469
# Epoch 2/200
# 3563/3563 [==============================] - 89s 25ms/step - loss: 0.4052 - accuracy: 0.8539 - val_loss: 0.4119 - val_accuracy: 0.8469
# RNN_model4 fit time: 0:03:53.717707

# %%
RNN_model1.summary()
# Out:
# Model: "sequential_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_23 (Embedding)    (None, None, 32)          32000
#
#  bidirectional_9 (Bidirectio  (None, 64)               4160
#  nal)
#
#  dense_39 (Dense)            (None, 32)                2080
#
#  dense_40 (Dense)            (None, 4)                 132
#
# =================================================================
# Total params: 38,372
# Trainable params: 38,372
# Non-trainable params: 0
# _________________________________________________________________

# %%
RNN_model1.evaluate(int_test_ds)
# Out:
# 238/238 [==============================] - 2s 7ms/step - loss: 0.4209 - accuracy: 0.8505
# [0.42092207074165344, 0.8505263328552246]

# %%
history_dict = history.history
history_dict.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
history_df=pd.DataFrame(history_dict)
history_df.tail().round(3)
# Out:
#     loss  accuracy  val_loss  val_accuracy
# 0  0.494     0.818     0.421         0.847
# 1  0.405     0.854     0.412         0.847

# %% [markdown]
# ### Plot Training Metrics (Loss and Accuracy)

# %%
plot_history(history)

# %% [markdown]
# ### Confusion matrices
# Using both `sklearn.metrics`. Then we visualize the confusion matrix and see what that tells us.

# %%
pred1= RNN_model1.predict(int_test_ds)
pred1=np.argmax(pred1, axis=1)
# Out:
# 238/238 [==============================] - 2s 7ms/step

# %%
# print_validation_report(int_val_ds, pred1)

# %%
# plot_confusion_matrix(int_val_ds,pred1)

# %% [markdown]
# ## RNN_Model2
#
# Unidirectional, No Regularization, Default output sequnece layer

# %% [markdown]
# ### Making the Model

# %%
# Define the model

RNN_model2 = tf.keras.Sequential([
                           #  text_vectorization
                              tf.keras.layers.Embedding(input_dim=len(text_vectorization.get_vocabulary())
                              ,output_dim=32
                              ,mask_zero=True)
                              ,tf.keras.layers.SimpleRNN(32) # Unidirectional
                              ,tf.keras.layers.Dense(32, activation='relu')
                              ,tf.keras.layers.Dense(4,activation='softmax') # 4 classes: World, Sports, Business, Sci.Tech
                          #    ,kernel_regularizer=tf.keras.regularizers.L2(0.001) # Without Regularization
])

# %%
# compile the model

RNN_model2.compile(optimizer='adam'
              ,loss=tf.keras.losses.SparseCategoricalCrossentropy()
              ,metrics=['accuracy'])

# %%
# Fit the model

start_time = dt.now()
history = RNN_model2.fit(int_train_ds
                    ,epochs=200
                    ,validation_data=int_val_ds
                    ,validation_steps=10
                    ,callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=1)]
                    )
end_time = dt.now()
print(f'RNN_model2 fit time: {end_time-start_time}')
# Out:
# Epoch 1/200
# 3563/3563 [==============================] - 59s 16ms/step - loss: 0.5648 - accuracy: 0.7809 - val_loss: 0.4769 - val_accuracy: 0.8375
# Epoch 2/200
# 3563/3563 [==============================] - 56s 16ms/step - loss: 0.4390 - accuracy: 0.8451 - val_loss: 0.4479 - val_accuracy: 0.8406
# Epoch 3/200
# 3563/3563 [==============================] - 57s 16ms/step - loss: 0.4117 - accuracy: 0.8531 - val_loss: 0.4390 - val_accuracy: 0.8469
# Epoch 4/200
# 3563/3563 [==============================] - 57s 16ms/step - loss: 0.3925 - accuracy: 0.8610 - val_loss: 0.4426 - val_accuracy: 0.8531
# Epoch 5/200
# 3563/3563 [==============================] - 56s 16ms/step - loss: 0.3765 - accuracy: 0.8668 - val_loss: 0.4652 - val_accuracy: 0.8469
# RNN_model2 fit time: 0:05:10.042012

# %%
RNN_model2.evaluate(int_test_ds)
# Out:
# 238/238 [==============================] - 1s 5ms/step - loss: 0.4778 - accuracy: 0.8337
# [0.4777921736240387, 0.8336842060089111]

# %%
history_dict = history.history
history_dict.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
print(history.history['val_loss'])
print(history.history['val_accuracy'])
# Out:
# [0.47694143652915955, 0.44791826605796814, 0.4389897286891937, 0.4425695836544037, 0.46516528725624084]
# [0.8374999761581421, 0.840624988079071, 0.846875011920929, 0.8531249761581421, 0.846875011920929]

# %%
history_df=pd.DataFrame(history_dict)
history_df.tail().round(3)
# Out:
#     loss  accuracy  val_loss  val_accuracy
# 0  0.565     0.781     0.477         0.837
# 1  0.439     0.845     0.448         0.841
# 2  0.412     0.853     0.439         0.847
# 3  0.392     0.861     0.443         0.853
# 4  0.376     0.867     0.465         0.847

# %% [markdown]
# ### Plot Training Metrics (Loss and Accuracy)

# %%
plot_history(history)

# %% [markdown]
# ### Confusion matrices
# Using both `sklearn.metrics`. Then we visualize the confusion matrix and see what that tells us.

# %%
pred2= RNN_model2.predict(int_test_ds)
# pred2=np.argmax(pred2, axis=1)
print('shape of preds: ', pred2.shape)
# Out:
# 238/238 [==============================] - 1s 5ms/step
# shape of preds:  (7600, 4)

# %%
pred2.shape
# Out:
# (7600, 4)

# %%
# print_validation_report(int_val_ds, pred2)

# %%
# plot_confusion_matrix(int_val_ds,pred2)

# %% [markdown]
# ## RNN_Model3
#
# Bidirectional, Regularization, Default output sequnece layer

# %% [markdown]
# ### Making the Model

# %%
# Define the model

RNN_model3 = tf.keras.Sequential([
                           #  text_vectorization
                              tf.keras.layers.Embedding(input_dim=len(text_vectorization.get_vocabulary())
                              ,output_dim=32
                              ,mask_zero=True)
                              ,tf.keras.layers.Bidirectional(tf.keras.layers.SimpleRNN(32)) # Bidirectional
                              ,tf.keras.layers.Dense(32, activation='relu')
                              ,tf.keras.layers.Dense(4,activation='softmax', kernel_regularizer=tf.keras.regularizers.L2(0.001)) # 4 classes: World, Sports, Business, Sci.Tech
                               # With Regularization
])

# %%
# compile the model

RNN_model3.compile(optimizer='adam'
              ,loss=tf.keras.losses.SparseCategoricalCrossentropy()
              ,metrics=['accuracy'])

# %%
# Fit the model

start_time = dt.now()
history = RNN_model3.fit(int_train_ds
                    ,epochs=200
                    ,validation_data=int_val_ds
                    ,validation_steps=10
                    ,callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=1)]
                    )
end_time = dt.now()
print(f'RNN_model2 fit time: {end_time-start_time}')
# Out:
# Epoch 1/200
# 3563/3563 [==============================] - 91s 25ms/step - loss: 0.5016 - accuracy: 0.8176 - val_loss: 0.4241 - val_accuracy: 0.8438
# Epoch 2/200
# 3563/3563 [==============================] - 88s 25ms/step - loss: 0.4099 - accuracy: 0.8539 - val_loss: 0.4069 - val_accuracy: 0.8562
# Epoch 3/200
# 3563/3563 [==============================] - 88s 25ms/step - loss: 0.3816 - accuracy: 0.8639 - val_loss: 0.3922 - val_accuracy: 0.8656
# Epoch 4/200
# 3563/3563 [==============================] - 88s 25ms/step - loss: 0.3592 - accuracy: 0.8725 - val_loss: 0.3965 - val_accuracy: 0.8594
# RNN_model2 fit time: 0:06:49.589148

# %%
RNN_model3.evaluate(int_test_ds)
# Out:
# 238/238 [==============================] - 2s 7ms/step - loss: 0.4344 - accuracy: 0.8479
# [0.43443378806114197, 0.8478947281837463]

# %%
history_dict = history.history
history_dict.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
print(history.history['val_loss'])
print(history.history['val_accuracy'])
# Out:
# [0.42408737540245056, 0.40693920850753784, 0.3922122120857239, 0.39650586247444153]
# [0.84375, 0.856249988079071, 0.8656250238418579, 0.859375]

# %%
history_df=pd.DataFrame(history_dict)
history_df.tail().round(3)
# Out:
#     loss  accuracy  val_loss  val_accuracy
# 0  0.502     0.818     0.424         0.844
# 1  0.410     0.854     0.407         0.856
# 2  0.382     0.864     0.392         0.866
# 3  0.359     0.873     0.397         0.859

# %% [markdown]
# ### Plot Training Metrics (Loss and Accuracy)

# %%
plot_history(history)

# %% [markdown]
# ### Confusion matrices
# Using both `sklearn.metrics`. Then we visualize the confusion matrix and see what that tells us.

# %%
pred3= RNN_model3.predict(int_test_ds)
pred3=np.argmax(pred3, axis=1)
# Out:
# 238/238 [==============================] - 2s 7ms/step

# %%
# print_validation_report(int_val_ds, pred3)

# %%
# plot_confusion_matrix(int_val_ds,pred3)

# %% [markdown]
# ## RNN_Model4
#
# Unidirectional, Regularization, default output sequnece layer

# %% [markdown]
# ### Making the Model

# %%
# Define the model

RNN_model4 = tf.keras.Sequential([
                           #  text_vectorization
                              tf.keras.layers.Embedding(input_dim=len(text_vectorization.get_vocabulary())
                              ,output_dim=32
                              ,mask_zero=True)
                              ,tf.keras.layers.SimpleRNN(32) # Uniidirectional
                              ,tf.keras.layers.Dense(32, activation='relu')
                              ,tf.keras.layers.Dense(4,activation='softmax', kernel_regularizer=tf.keras.regularizers.L2(0.001)) # With Regularization
])

# %%
# compile the model

RNN_model4.compile(optimizer='adam'
              ,loss=tf.keras.losses.SparseCategoricalCrossentropy()
              ,metrics=['accuracy'])

# %%
# Fit the model

start_time = dt.now()
history = RNN_model4.fit(int_train_ds
                    ,epochs=200
                    ,validation_data=int_val_ds
                    ,validation_steps=10
                    ,callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=1)]
                    )
end_time = dt.now()
print(f'RNN_model4 fit time: {end_time-start_time}')
# Out:
# Epoch 1/200
# 3563/3563 [==============================] - 58s 16ms/step - loss: 0.5638 - accuracy: 0.7864 - val_loss: 0.4810 - val_accuracy: 0.8406
# Epoch 2/200
# 3563/3563 [==============================] - 55s 15ms/step - loss: 0.4467 - accuracy: 0.8446 - val_loss: 0.4502 - val_accuracy: 0.8375
# RNN_model4 fit time: 0:02:18.325973

# %%
RNN_model4.evaluate(int_test_ds)
# Out:
# 238/238 [==============================] - 1s 5ms/step - loss: 0.4558 - accuracy: 0.8411
# [0.4558011591434479, 0.8410526514053345]

# %%
history_dict = history.history
history_dict.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
history_df=pd.DataFrame(history_dict)
history_df.tail().round(3)
# Out:
#     loss  accuracy  val_loss  val_accuracy
# 0  0.564     0.786     0.481         0.841
# 1  0.447     0.845     0.450         0.837

# %% [markdown]
# ### Plot Training Metrics (Loss and Accuracy)

# %%
plot_history(history)

# %% [markdown]
# ### Confusion matrices
# Using both `sklearn.metrics`. Then we visualize the confusion matrix and see what that tells us.

# %%
pred4= RNN_model4.predict(int_test_ds)
pred4=np.argmax(pred4, axis=1)
# Out:
# 238/238 [==============================] - 1s 5ms/step

# %%
# print_validation_report(int_val_ds, pred4)

# %%
# plot_confusion_matrix(val_ds,pred4)

# %% [markdown]
# ## RNN_Model5
#
# Bidirectional, Regularization And fixed output sequnece layer

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <b>tf.keras.layers.TextVectorization</b><br>
#     https://www.tensorflow.org/api_docs/python/tf/keras/layers/TextVectorization
#     </div>

# %%
text_only_train_ds = train_ds.map(lambda x, y: x)

# %%
# Text Vectorizer

max_length = 150
max_tokens = 1000
text_vectorization = layers.TextVectorization(
    max_tokens=max_tokens,
    output_mode="int",
    output_sequence_length=max_length, # fixed output sequence length
    standardize=custom_stopwords
)
text_vectorization.adapt(text_only_train_ds)

int_train_ds = train_ds.map(
    lambda x, y: (text_vectorization(x), y),
    num_parallel_calls=4)
int_val_ds = val_ds.map(
    lambda x, y: (text_vectorization(x), y),
    num_parallel_calls=4)
int_test_ds = test_ds.map(
    lambda x, y: (text_vectorization(x), y),
    num_parallel_calls=4)

# %%
# for text in text_only_train_ds:
#     print(f"Get first batch of {text.shape[0]} news articles.\n")
#     print(f"Here is the first news article:\n\n{text[0]}.")
#     break
# Out:
# Get first batch of 32 news articles.
#
# Here is the first news article:
#
# b'AMD #39;s new dual-core Opteron chip is designed mainly for corporate computing applications, including databases, Web services, and financial transactions.'.

# %%
# %%time
# encoder = tf.keras.layers.experimental.preprocessing.TextVectorization(
#     max_tokens=1000,
#     output_sequence_length=150, # using output sequence length
#     standardize=custom_stopwords)
# encoder.adapt(train_ds.map(lambda text, label: text))
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function <lambda> at 0x7fb3da0d6f80> and will run it as-is.
# Cause: could not parse the source code of <function <lambda> at 0x7fb3da0d6f80>: no matching AST found among candidates:
#
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function <lambda> at 0x7fb3da0d6f80> and will run it as-is.
# Cause: could not parse the source code of <function <lambda> at 0x7fb3da0d6f80>: no matching AST found among candidates:
#
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# CPU times: user 7.22 s, sys: 612 ms, total: 7.83 s
# Wall time: 6.22 s

# %% [markdown]
# ### Making the Model

# %%
# Define the model

RNN_model5 = tf.keras.Sequential([
                           #  text_vectorization
                              tf.keras.layers.Embedding(input_dim=len(text_vectorization.get_vocabulary())
                              ,output_dim=32
                              ,mask_zero=True)
                              ,tf.keras.layers.SimpleRNN(32) # Uniidirectional
                              ,tf.keras.layers.Dense(32, activation='relu')
                              ,tf.keras.layers.Dense(4,activation='softmax', kernel_regularizer=tf.keras.regularizers.L2(0.001)) # With Regularization
])

# %%
# compile the model

RNN_model5.compile(optimizer='adam'
              ,loss=tf.keras.losses.SparseCategoricalCrossentropy()
              ,metrics=['accuracy'])

# %%
# Fit the model

start_time = dt.now()
history = RNN_model5.fit(int_train_ds
                    ,epochs=200
                    ,validation_data=int_val_ds
                    ,validation_steps=10
                    ,callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=1)]
                    )
end_time = dt.now()
print(f'RNN_model5 fit time: {end_time-start_time}')
# Out:
# Epoch 1/200
# 3563/3563 [==============================] - 213s 59ms/step - loss: 0.5452 - accuracy: 0.8006 - val_loss: 0.4670 - val_accuracy: 0.8406
# Epoch 2/200
# 3563/3563 [==============================] - 208s 58ms/step - loss: 0.4421 - accuracy: 0.8454 - val_loss: 0.4374 - val_accuracy: 0.8438
# Epoch 3/200
# 3563/3563 [==============================] - 209s 59ms/step - loss: 0.4165 - accuracy: 0.8538 - val_loss: 0.4362 - val_accuracy: 0.8438
# RNN_model5 fit time: 0:12:14.212008

# %%
RNN_model5.evaluate(int_test_ds)
# Out:
# 238/238 [==============================] - 4s 15ms/step - loss: 0.4538 - accuracy: 0.8436
# [0.4537889063358307, 0.8435526490211487]

# %%
history_dict = history.history
history_dict.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
history_df=pd.DataFrame(history_dict)
history_df.tail().round(3)
# Out:
#     loss  accuracy  val_loss  val_accuracy
# 0  0.545     0.801     0.467         0.841
# 1  0.442     0.845     0.437         0.844
# 2  0.417     0.854     0.436         0.844

# %% [markdown]
# ### Plot Training Metrics (Loss and Accuracy)

# %%
plot_history(history)

# %% [markdown]
# ### Confusion matrices
# Using both `sklearn.metrics`. Then we visualize the confusion matrix and see what that tells us.

# %%
pred4= RNN_model5.predict(int_test_ds)
pred4=np.argmax(pred4, axis=1)
# Out:
# 238/238 [==============================] - 3s 13ms/step

# %%
# print_validation_report(int_val_ds, pred4)

# %%
# plot_confusion_matrix(val_ds,pred4)
