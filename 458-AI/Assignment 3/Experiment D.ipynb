# %% [markdown]
# <img src="https://github.com/djp840/MSDS_458_Public/blob/master/images/NorthwesternHeader.png?raw=1">

# %% [markdown]
# ## MSDS458 Research Assignment 3

# %% [markdown]
# ## Data Preperation

# %% [markdown]
# ### Research Assignment Reporting Functions

# %%
# Accuracy and loss Line plots visual
def plot_history(history):
  losses = history.history['loss']
  accs = history.history['accuracy']
  val_losses = history.history['val_loss']
  val_accs = history.history['val_accuracy']
  epochs = len(losses)

  plt.figure(figsize=(16, 4))
  for i, metrics in enumerate(zip([losses, accs], [val_losses, val_accs], ['Loss', 'Accuracy'])):
    plt.subplot(1, 2, i + 1)
    plt.plot(range(epochs), metrics[0], label='Training {}'.format(metrics[2]))
    plt.plot(range(epochs), metrics[1], label='Validation {}'.format(metrics[2]))
    plt.legend()
  plt.show()

# %%
# Shows Accuracy & Root Mean Square Error scores
def print_validation_report(y_test, predictions):
    print("Classification Report")
    print(classification_report(y_test, predictions))
    print('Accuracy Score: {}'.format(accuracy_score(y_test, predictions)))
    print('Root Mean Square Error: {}'.format(np.sqrt(MSE(y_test, predictions))))

# %%
# Confusion Matrix visual
def plot_confusion_matrix(y_true, y_pred):
    mtx = confusion_matrix(y_true, y_pred)
    fig, ax = plt.subplots(figsize=(8,8))
    sns.heatmap(mtx, annot=True, fmt='d', linewidths=.75,  cbar=False, ax=ax,cmap='Blues',linecolor='white')
    #  square=True,
    plt.ylabel('true label')
    plt.xlabel('predicted label')

# %% [markdown]
# ### Import packages

# %%
import datetime
from datetime import datetime as dt 
from packaging import version
from collections import Counter
import numpy as np
import pandas as pd
import time
import string
import nltk
from nltk.corpus import stopwords
from collections import Counter
import re

import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

from sklearn.metrics import confusion_matrix, classification_report
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import mean_squared_error as MSE
from sklearn.metrics import accuracy_score

import tensorflow as tf
from tensorflow import keras
import tensorflow_datasets as tfds
from tensorflow.keras import layers
from tensorflow.keras.layers import TextVectorization

# %%
# %matplotlib inline
np.set_printoptions(precision=3, suppress=True)

# %% [markdown]
# ### Stopword Function

# %%
def custom_stopwords(input_text):
    lowercase = tf.strings.lower(input_text)
    stripped_punct = tf.strings.regex_replace(lowercase
                                  ,'[%s]' % re.escape(string.punctuation)
                                  ,'')
    return tf.strings.regex_replace(stripped_punct, r'\b(' + r'|'.join(STOPWORDS) + r')\b\s*',"")

# %% [markdown]
# ### Analyze AG_NEWS_SUBSET Data <br>
#
# AG is a collection of more than 1 million news articles. News articles have been gathered from more than 2000 news sources by ComeToMyHead in more than 1 year of activity. ComeToMyHead is an academic news search engine which has been running since July, 2004. The dataset is provided by the academic comunity for research purposes in data mining (clustering, classification, etc), information retrieval (ranking, search, etc), xml, data compression, data streaming, and any other non-commercial activity.<br>
#
# For more information, please refer to the link http://www.di.unipi.it/~gulli/AG_corpus_of_news_articles.html<br>
#
#
# The AG's news topic classification dataset is constructed by choosing 4 largest classes (**World**, **Sports**, **Business**, and **Sci/Tech**) from the original corpus. Each class contains 30,000 training samples and 1,900 testing samples. The total number of training samples is 120,000 and testing 7,600.<br>
#
# Homepage: https://arxiv.org/abs/1509.01626<br>
#
# Source code: tfds.text.AGNewsSubset
#
# Versions:
#
# 1.0.0 (default): No release notes.
# Download size: 11.24 MiB
#
# Dataset size: 35.79 MiB

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <b>More Technical</b>: Throughout the notebook. This types of boxes provide more technical details and extra references about what you are seeing. They contain helpful tips, but you can safely skip them the first time you run through the code.
# </div>

# %%
#!conda install -c anaconda tensorflow-datasets --y
#!pip install -c anaconda tensorflow-datasets --y

# %% [markdown]
# ### Load AG_NEWS_SUBSET News Articles Dataset

# %%
# register  ag_news_subset so that tfds.load doesn't generate a checksum (mismatch) error
# !python -m tensorflow_datasets.scripts.download_and_prepare --register_checksums --datasets=ag_news_subset

dataset, info = tfds.load('ag_news_subset', with_info=True,  split=['train[:114000]','train[114000:]', 'test'],
                          batch_size = 32, as_supervised=True)
train_ds, val_ds, test_ds = dataset
# Out:
# W1103 01:15:15.758884 139991763670912 download_and_prepare.py:43] ***`tfds build` should be used instead of `download_and_prepare`.***
# INFO[build.py]: Loading dataset ag_news_subset from imports: tensorflow_datasets.text.ag_news_subset
# 2022-11-03 01:15:15.916113: W tensorflow/core/platform/cloud/google_auth_provider.cc:184] All attempts to get a Google authentication bearer token failed, returning an empty token. Retrieving token from files failed with "NOT_FOUND: Could not locate the credentials file.". Retrieving token from GCE failed with "NOT_FOUND: Error executing an HTTP request: HTTP response code 404".
# INFO[dataset_info.py]: Load pre-computed DatasetInfo (eg: splits, num examples,...) from GCS: ag_news_subset/1.0.0
# INFO[dataset_info.py]: Load dataset info from /tmp/tmp6t8acjd1tfds
# INFO[dataset_info.py]: Field info.splits from disk and from code do not match. Keeping the one from code.
# INFO[dataset_info.py]: Field info.supervised_keys from disk and from code do not match. Keeping the one from code.
# INFO[dataset_info.py]: Field info.module_name from disk and from code do not match. Keeping the one from code.
# INFO[build.py]: download_and_prepare for dataset ag_news_subset/1.0.0...
# INFO[dataset_builder.py]: Generating dataset ag_news_subset (/root/tensorflow_datasets/ag_news_subset/1.0.0)
# Downloading and preparing dataset 11.24 MiB (download: 11.24 MiB, generated: 35.79 MiB, total: 47.03 MiB) to /root/tensorflow_datasets/ag_news_subset/1.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
#
#
#
#
# INFO[download_manager.py]: Downloading https://drive.google.com/uc?export=download&id=0Bz8a_Dbh9QhbUDNpeUdjb0wxRms into /root/tensorflow_datasets/downloads/ucexport_download_id_0Bz8a_Dbh9QhbUDNpeUdjb0wxj4g1umFAV8OV-uDwxSJR0LdxO_k1jxMuFWwAfNX9jos.tmp.88cf2abde11045e8ad518488c4152721...
# Dl Completed...: 0 url [00:00, ? url/s]
#
# Extraction completed...: 0 file [00:00, ? file/s]
# Dl Completed...:   0% 0/1 [00:00<?, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
#
# Dl Completed...:   0% 0/1 [00:11<?, ? url/s]
# Dl Size...:   0% 0/11 [00:11<?, ? MiB/s]
#
# Extraction completed...: 0 file [00:11, ? file/s]
# Dl Completed...:   0% 0/1 [00:11<?, ? url/s]
# Dl Size...:   9% 1/11 [00:11<01:58, 11.86s/ MiB]
#
# Dl Completed...:   0% 0/1 [00:11<?, ? url/s]
# Dl Size...:  18% 2/11 [00:11<01:46, 11.86s/ MiB]
#
# Dl Completed...:   0% 0/1 [00:11<?, ? url/s]
# Dl Size...:  27% 3/11 [00:11<01:34, 11.86s/ MiB]
#
# Extraction completed...: 0 file [00:11, ? file/s]
# Dl Completed...:   0% 0/1 [00:12<?, ? url/s]
# Dl Size...:  36% 4/11 [00:12<00:16,  2.29s/ MiB]
#
# Dl Completed...:   0% 0/1 [00:12<?, ? url/s]
# Dl Size...:  45% 5/11 [00:12<00:13,  2.29s/ MiB]
#
# Dl Completed...:   0% 0/1 [00:12<?, ? url/s]
# Dl Size...:  55% 6/11 [00:12<00:11,  2.29s/ MiB]
#
# Dl Completed...:   0% 0/1 [00:12<?, ? url/s]
# Dl Size...:  64% 7/11 [00:12<00:09,  2.29s/ MiB]
#
# Dl Completed...:   0% 0/1 [00:12<?, ? url/s]
# Dl Size...:  73% 8/11 [00:12<00:06,  2.29s/ MiB]
#
# Dl Completed...:   0% 0/1 [00:12<?, ? url/s]
# Dl Size...:  82% 9/11 [00:12<00:04,  2.29s/ MiB]
#
# Dl Completed...:   0% 0/1 [00:12<?, ? url/s]
# Dl Size...:  91% 10/11 [00:12<00:02,  2.29s/ MiB]
#
# Dl Completed...:   0% 0/1 [00:12<?, ? url/s]
# Dl Size...: 100% 11/11 [00:12<00:00,  2.29s/ MiB]
#
# Dl Completed...: 100% 1/1 [00:12<00:00, 12.08s/ url]
# Dl Size...: 100% 11/11 [00:12<00:00,  2.29s/ MiB]
#
# Dl Completed...: 100% 1/1 [00:12<00:00, 12.08s/ url]
# Dl Size...: 100% 11/11 [00:12<00:00,  2.29s/ MiB]
#
# Extraction completed...:   0% 0/1 [00:12<?, ? file/s]
#
# Dl Completed...: 100% 1/1 [00:12<00:00, 12.08s/ url]
# Dl Size...: 100% 11/11 [00:12<00:00,  2.29s/ MiB]
#
# Extraction completed...: 100% 1/1 [00:12<00:00, 12.39s/ file]
# Dl Size...: 100% 11/11 [00:12<00:00,  1.13s/ MiB]
# Dl Completed...: 100% 1/1 [00:12<00:00, 12.39s/ url]
# Generating splits...:   0% 0/2 [00:00<?, ? splits/s]
# Generating train examples...:   0% 0/120000 [00:00<?, ? examples/s]
# Generating train examples...:   1% 988/120000 [00:00<00:12, 9870.78 examples/s]
# Generating train examples...:   2% 1980/120000 [00:00<00:11, 9895.75 examples/s]
# Generating train examples...:   2% 2970/120000 [00:00<00:12, 9625.24 examples/s]
# Generating train examples...:   3% 3936/120000 [00:00<00:12, 9636.96 examples/s]
# Generating train examples...:   4% 4901/120000 [00:00<00:12, 9488.00 examples/s]
# Generating train examples...:   5% 5851/120000 [00:00<00:12, 9407.22 examples/s]
# Generating train examples...:   6% 6815/120000 [00:00<00:11, 9478.74 examples/s]
# Generating train examples...:   6% 7764/120000 [00:00<00:12, 8776.70 examples/s]
# Generating train examples...:   7% 8662/120000 [00:00<00:12, 8835.75 examples/s]
# Generating train examples...:   8% 9635/120000 [00:01<00:12, 9097.91 examples/s]
# Generating train examples...:   9% 10580/120000 [00:01<00:11, 9200.42 examples/s]
# Generating train examples...:  10% 11576/120000 [00:01<00:11, 9425.80 examples/s]
# Generating train examples...:  10% 12523/120000 [00:01<00:11, 9380.21 examples/s]
# Generating train examples...:  11% 13501/120000 [00:01<00:11, 9498.46 examples/s]
# Generating train examples...:  12% 14453/120000 [00:01<00:11, 9406.89 examples/s]
# Generating train examples...:  13% 15396/120000 [00:01<00:11, 9411.28 examples/s]
# Generating train examples...:  14% 16368/120000 [00:01<00:10, 9501.04 examples/s]
# Generating train examples...:  14% 17319/120000 [00:01<00:11, 9316.19 examples/s]
# Generating train examples...:  15% 18252/120000 [00:01<00:11, 9042.14 examples/s]
# Generating train examples...:  16% 19175/120000 [00:02<00:11, 9095.75 examples/s]
# Generating train examples...:  17% 20090/120000 [00:02<00:10, 9109.46 examples/s]
# Generating train examples...:  18% 21028/120000 [00:02<00:10, 9189.08 examples/s]
# Generating train examples...:  18% 21948/120000 [00:02<00:10, 9058.94 examples/s]
# Generating train examples...:  19% 22855/120000 [00:02<00:11, 8751.91 examples/s]
# Generating train examples...:  20% 23770/120000 [00:02<00:10, 8864.15 examples/s]
# Generating train examples...:  21% 24713/120000 [00:02<00:10, 9027.93 examples/s]
# Generating train examples...:  21% 25618/120000 [00:02<00:12, 7595.82 examples/s]
# Generating train examples...:  22% 26417/120000 [00:03<00:15, 6236.15 examples/s]
# Generating train examples...:  23% 27103/120000 [00:03<00:16, 5599.67 examples/s]
# Generating train examples...:  23% 27712/120000 [00:03<00:17, 5183.15 examples/s]
# Generating train examples...:  24% 28264/120000 [00:03<00:18, 5018.33 examples/s]
# Generating train examples...:  24% 28799/120000 [00:03<00:17, 5094.77 examples/s]
# Generating train examples...:  24% 29326/120000 [00:03<00:17, 5090.78 examples/s]
# Generating train examples...:  25% 29851/120000 [00:03<00:17, 5130.81 examples/s]
# Generating train examples...:  25% 30373/120000 [00:03<00:18, 4792.04 examples/s]
# Generating train examples...:  26% 30861/120000 [00:04<00:21, 4238.79 examples/s]
# Generating train examples...:  26% 31300/120000 [00:04<00:20, 4236.27 examples/s]
# Generating train examples...:  26% 31734/120000 [00:04<00:21, 4184.18 examples/s]
# Generating train examples...:  27% 32210/120000 [00:04<00:20, 4337.42 examples/s]
# Generating train examples...:  27% 32724/120000 [00:04<00:19, 4558.51 examples/s]
# Generating train examples...:  28% 33187/120000 [00:04<00:19, 4508.30 examples/s]
# Generating train examples...:  28% 33679/120000 [00:04<00:18, 4625.30 examples/s]
# Generating train examples...:  28% 34146/120000 [00:04<00:19, 4319.49 examples/s]
# Generating train examples...:  29% 34584/120000 [00:04<00:20, 4109.41 examples/s]
# Generating train examples...:  29% 35001/120000 [00:05<00:21, 4039.08 examples/s]
# Generating train examples...:  30% 35409/120000 [00:05<00:21, 3914.15 examples/s]
# Generating train examples...:  30% 35803/120000 [00:05<00:23, 3636.06 examples/s]
# Generating train examples...:  30% 36278/120000 [00:05<00:21, 3933.97 examples/s]
# Generating train examples...:  31% 36717/120000 [00:05<00:20, 4059.05 examples/s]
# Generating train examples...:  31% 37129/120000 [00:05<00:21, 3814.30 examples/s]
# Generating train examples...:  31% 37604/120000 [00:05<00:20, 4070.75 examples/s]
# Generating train examples...:  32% 38039/120000 [00:05<00:19, 4148.76 examples/s]
# Generating train examples...:  32% 38554/120000 [00:05<00:18, 4433.62 examples/s]
# Generating train examples...:  33% 39083/120000 [00:05<00:17, 4681.98 examples/s]
# Generating train examples...:  33% 39556/120000 [00:06<00:17, 4609.62 examples/s]
# Generating train examples...:  33% 40049/120000 [00:06<00:17, 4700.84 examples/s]
# Generating train examples...:  34% 40537/120000 [00:06<00:16, 4751.19 examples/s]
# Generating train examples...:  34% 41028/120000 [00:06<00:16, 4796.21 examples/s]
# Generating train examples...:  35% 41509/120000 [00:06<00:17, 4524.31 examples/s]
# Generating train examples...:  35% 41966/120000 [00:06<00:20, 3830.91 examples/s]
# Generating train examples...:  35% 42401/120000 [00:06<00:19, 3962.25 examples/s]
# Generating train examples...:  36% 42814/120000 [00:06<00:20, 3821.16 examples/s]
# Generating train examples...:  36% 43208/120000 [00:06<00:20, 3832.15 examples/s]
# Generating train examples...:  36% 43630/120000 [00:07<00:19, 3889.91 examples/s]
# Generating train examples...:  37% 44025/120000 [00:07<00:19, 3800.77 examples/s]
# Generating train examples...:  37% 44410/120000 [00:07<00:24, 3035.00 examples/s]
# Generating train examples...:  37% 44801/120000 [00:07<00:23, 3245.04 examples/s]
# Generating train examples...:  38% 45149/120000 [00:07<00:23, 3133.43 examples/s]
# Generating train examples...:  38% 45507/120000 [00:07<00:22, 3242.35 examples/s]
# Generating train examples...:  38% 45845/120000 [00:07<00:22, 3276.11 examples/s]
# Generating train examples...:  39% 46346/120000 [00:07<00:19, 3755.89 examples/s]
# Generating train examples...:  39% 46847/120000 [00:08<00:17, 4111.36 examples/s]
# Generating train examples...:  39% 47355/120000 [00:08<00:16, 4386.86 examples/s]
# Generating train examples...:  40% 47802/120000 [00:08<00:16, 4349.88 examples/s]
# Generating train examples...:  40% 48313/120000 [00:08<00:15, 4570.34 examples/s]
# Generating train examples...:  41% 48775/120000 [00:08<00:15, 4502.58 examples/s]
# Generating train examples...:  41% 49229/120000 [00:08<00:20, 3437.61 examples/s]
# Generating train examples...:  41% 49723/120000 [00:08<00:18, 3798.80 examples/s]
# Generating train examples...:  42% 50140/120000 [00:08<00:21, 3265.19 examples/s]
# Generating train examples...:  42% 50587/120000 [00:09<00:19, 3547.54 examples/s]
# Generating train examples...:  43% 51103/120000 [00:09<00:17, 3950.69 examples/s]
# Generating train examples...:  43% 51553/120000 [00:09<00:16, 4095.06 examples/s]
# Generating train examples...:  43% 52056/120000 [00:09<00:15, 4350.10 examples/s]
# Generating train examples...:  44% 52511/120000 [00:09<00:16, 4170.27 examples/s]
# Generating train examples...:  44% 52943/120000 [00:09<00:16, 4165.70 examples/s]
# Generating train examples...:  44% 53370/120000 [00:09<00:16, 3952.98 examples/s]
# Generating train examples...:  45% 53774/120000 [00:09<00:17, 3838.51 examples/s]
# Generating train examples...:  45% 54164/120000 [00:09<00:17, 3811.75 examples/s]
# Generating train examples...:  45% 54575/120000 [00:09<00:16, 3894.17 examples/s]
# Generating train examples...:  46% 55071/120000 [00:10<00:15, 4195.87 examples/s]
# Generating train examples...:  46% 55579/120000 [00:10<00:14, 4448.25 examples/s]
# Generating train examples...:  47% 56028/120000 [00:10<00:15, 4100.36 examples/s]
# Generating train examples...:  47% 56446/120000 [00:10<00:15, 4122.09 examples/s]
# Generating train examples...:  47% 56952/120000 [00:10<00:14, 4386.50 examples/s]
# Generating train examples...:  48% 57396/120000 [00:10<00:14, 4323.90 examples/s]
# Generating train examples...:  48% 57833/120000 [00:10<00:15, 3971.34 examples/s]
# Generating train examples...:  49% 58260/120000 [00:10<00:15, 4052.16 examples/s]
# Generating train examples...:  49% 58672/120000 [00:10<00:16, 3657.41 examples/s]
# Generating train examples...:  49% 59048/120000 [00:11<00:17, 3479.57 examples/s]
# Generating train examples...:  50% 59480/120000 [00:11<00:17, 3541.64 examples/s]
# Generating train examples...:  50% 59840/120000 [00:11<00:18, 3246.88 examples/s]
# Generating train examples...:  50% 60332/120000 [00:11<00:16, 3675.97 examples/s]
# Generating train examples...:  51% 60712/120000 [00:11<00:17, 3470.97 examples/s]
# Generating train examples...:  51% 61207/120000 [00:11<00:15, 3859.93 examples/s]
# Generating train examples...:  51% 61629/120000 [00:11<00:14, 3956.54 examples/s]
# Generating train examples...:  52% 62061/120000 [00:11<00:14, 3976.78 examples/s]
# Generating train examples...:  52% 62466/120000 [00:12<00:14, 3866.45 examples/s]
# Generating train examples...:  52% 62858/120000 [00:12<00:16, 3554.16 examples/s]
# Generating train examples...:  53% 63355/120000 [00:12<00:14, 3933.08 examples/s]
# Generating train examples...:  53% 63801/120000 [00:12<00:13, 4078.43 examples/s]
# Generating train examples...:  54% 64247/120000 [00:12<00:13, 4184.58 examples/s]
# Generating train examples...:  54% 64749/120000 [00:12<00:12, 4423.45 examples/s]
# Generating train examples...:  54% 65251/120000 [00:12<00:11, 4596.93 examples/s]
# Generating train examples...:  55% 65746/120000 [00:12<00:11, 4699.65 examples/s]
# Generating train examples...:  55% 66252/120000 [00:12<00:11, 4763.32 examples/s]
# Generating train examples...:  56% 66731/120000 [00:13<00:16, 3194.89 examples/s]
# Generating train examples...:  56% 67120/120000 [00:13<00:16, 3156.08 examples/s]
# Generating train examples...:  56% 67484/120000 [00:13<00:16, 3243.24 examples/s]
# Generating train examples...:  57% 67918/120000 [00:13<00:14, 3510.57 examples/s]
# Generating train examples...:  57% 68409/120000 [00:13<00:13, 3871.39 examples/s]
# Generating train examples...:  57% 68824/120000 [00:13<00:13, 3829.42 examples/s]
# Generating train examples...:  58% 69227/120000 [00:13<00:13, 3754.24 examples/s]
# Generating train examples...:  58% 69926/120000 [00:13<00:10, 4638.35 examples/s]
# Generating train examples...:  59% 70917/120000 [00:13<00:08, 6117.10 examples/s]
# Generating train examples...:  60% 71852/120000 [00:14<00:06, 7041.70 examples/s]
# Generating train examples...:  61% 72815/120000 [00:14<00:06, 7792.47 examples/s]
# Generating train examples...:  62% 73813/120000 [00:14<00:05, 8432.78 examples/s]
# Generating train examples...:  62% 74670/120000 [00:14<00:05, 8465.52 examples/s]
# Generating train examples...:  63% 75648/120000 [00:14<00:05, 8852.96 examples/s]
# Generating train examples...:  64% 76605/120000 [00:14<00:04, 9064.28 examples/s]
# Generating train examples...:  65% 77527/120000 [00:14<00:04, 9109.11 examples/s]
# Generating train examples...:  65% 78529/120000 [00:14<00:04, 9379.48 examples/s]
# Generating train examples...:  66% 79470/120000 [00:14<00:04, 9199.87 examples/s]
# Generating train examples...:  67% 80393/120000 [00:14<00:04, 9175.57 examples/s]
# Generating train examples...:  68% 81353/120000 [00:15<00:04, 9300.86 examples/s]
# Generating train examples...:  69% 82348/120000 [00:15<00:03, 9493.50 examples/s]
# Generating train examples...:  69% 83299/120000 [00:15<00:03, 9381.76 examples/s]
# Generating train examples...:  70% 84239/120000 [00:15<00:03, 9029.07 examples/s]
# Generating train examples...:  71% 85165/120000 [00:15<00:03, 9093.64 examples/s]
# Generating train examples...:  72% 86077/120000 [00:15<00:03, 8956.47 examples/s]
# Generating train examples...:  73% 87026/120000 [00:15<00:03, 9107.73 examples/s]
# Generating train examples...:  73% 87978/120000 [00:15<00:03, 9227.77 examples/s]
# Generating train examples...:  74% 88918/120000 [00:15<00:03, 9276.42 examples/s]
# Generating train examples...:  75% 89872/120000 [00:15<00:03, 9352.39 examples/s]
# Generating train examples...:  76% 90871/120000 [00:16<00:03, 9539.21 examples/s]
# Generating train examples...:  77% 91826/120000 [00:16<00:03, 9383.72 examples/s]
# Generating train examples...:  77% 92812/120000 [00:16<00:02, 9523.95 examples/s]
# Generating train examples...:  78% 93766/120000 [00:16<00:02, 9244.12 examples/s]
# Generating train examples...:  79% 94693/120000 [00:16<00:02, 9140.83 examples/s]
# Generating train examples...:  80% 95648/120000 [00:16<00:02, 9259.33 examples/s]
# Generating train examples...:  80% 96576/120000 [00:16<00:02, 9252.26 examples/s]
# Generating train examples...:  81% 97507/120000 [00:16<00:02, 9269.04 examples/s]
# Generating train examples...:  82% 98503/120000 [00:16<00:02, 9471.61 examples/s]
# Generating train examples...:  83% 99451/120000 [00:17<00:02, 9464.51 examples/s]
# Generating train examples...:  84% 100398/120000 [00:17<00:02, 9390.88 examples/s]
# Generating train examples...:  84% 101362/120000 [00:17<00:01, 9462.12 examples/s]
# Generating train examples...:  85% 102309/120000 [00:17<00:01, 9428.33 examples/s]
# Generating train examples...:  86% 103253/120000 [00:17<00:01, 9097.25 examples/s]
# Generating train examples...:  87% 104173/120000 [00:17<00:01, 9126.19 examples/s]
# Generating train examples...:  88% 105088/120000 [00:17<00:01, 8634.36 examples/s]
# Generating train examples...:  88% 105958/120000 [00:17<00:01, 8636.75 examples/s]
# Generating train examples...:  89% 106872/120000 [00:17<00:01, 8779.53 examples/s]
# Generating train examples...:  90% 107768/120000 [00:17<00:01, 8830.83 examples/s]
# Generating train examples...:  91% 108698/120000 [00:18<00:01, 8968.32 examples/s]
# Generating train examples...:  91% 109669/120000 [00:18<00:01, 9187.38 examples/s]
# Generating train examples...:  92% 110639/120000 [00:18<00:01, 9336.92 examples/s]
# Generating train examples...:  93% 111575/120000 [00:18<00:00, 9319.65 examples/s]
# Generating train examples...:  94% 112508/120000 [00:18<00:00, 9186.23 examples/s]
# Generating train examples...:  95% 113430/120000 [00:18<00:00, 9193.98 examples/s]
# Generating train examples...:  95% 114351/120000 [00:18<00:00, 9150.67 examples/s]
# Generating train examples...:  96% 115326/120000 [00:18<00:00, 9326.62 examples/s]
# Generating train examples...:  97% 116269/120000 [00:18<00:00, 9356.98 examples/s]
# Generating train examples...:  98% 117206/120000 [00:18<00:00, 9116.97 examples/s]
# Generating train examples...:  98% 118166/120000 [00:19<00:00, 9256.10 examples/s]
# Generating train examples...:  99% 119094/120000 [00:19<00:00, 9237.56 examples/s]
#
# Shuffling /root/tensorflow_datasets/ag_news_subset/1.0.0.incompleteCVKZ51/ag_news_subset-train.tfrecord*...:   0% 0/120000 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/ag_news_subset/1.0.0.incompleteCVKZ51/ag_news_subset-train.tfrecord*...:   3% 3481/120000 [00:00<00:03, 34808.46 examples/s]
# Shuffling /root/tensorflow_datasets/ag_news_subset/1.0.0.incompleteCVKZ51/ag_news_subset-train.tfrecord*...:  38% 45259/120000 [00:00<00:00, 260066.91 examples/s]
# Shuffling /root/tensorflow_datasets/ag_news_subset/1.0.0.incompleteCVKZ51/ag_news_subset-train.tfrecord*...:  75% 89720/120000 [00:00<00:00, 344316.38 examples/s]
# INFO[writer.py]: Done writing /root/tensorflow_datasets/ag_news_subset/1.0.0.incompleteCVKZ51/ag_news_subset-train.tfrecord*. Number of examples: 120000 (shards: [120000])
# Generating splits...:  50% 1/2 [00:19<00:19, 19.66s/ splits]
# Generating test examples...:   0% 0/7600 [00:00<?, ? examples/s]
# Generating test examples...:  12% 898/7600 [00:00<00:00, 8972.97 examples/s]
# Generating test examples...:  24% 1797/7600 [00:00<00:00, 8979.83 examples/s]
# Generating test examples...:  37% 2789/7600 [00:00<00:00, 9405.92 examples/s]
# Generating test examples...:  50% 3781/7600 [00:00<00:00, 9607.16 examples/s]
# Generating test examples...:  62% 4742/7600 [00:00<00:00, 9569.51 examples/s]
# Generating test examples...:  75% 5732/7600 [00:00<00:00, 9680.60 examples/s]
# Generating test examples...:  88% 6701/7600 [00:00<00:00, 9664.63 examples/s]
#
# Shuffling /root/tensorflow_datasets/ag_news_subset/1.0.0.incompleteCVKZ51/ag_news_subset-test.tfrecord*...:   0% 0/7600 [00:00<?, ? examples/s]
# INFO[writer.py]: Done writing /root/tensorflow_datasets/ag_news_subset/1.0.0.incompleteCVKZ51/ag_news_subset-test.tfrecord*. Number of examples: 7600 (shards: [7600])
# Dataset ag_news_subset downloaded and prepared to /root/tensorflow_datasets/ag_news_subset/1.0.0. Subsequent calls will reuse this data.
# INFO[build.py]: Dataset generation complete...
#
# tfds.core.DatasetInfo(
#     name='ag_news_subset',
#     full_name='ag_news_subset/1.0.0',
#     description="""
#     AG is a collection of more than 1 million news articles.
#     News articles have been gathered from more than 2000  news sources by ComeToMyHead in more than 1 year of activity.
#     ComeToMyHead is an academic news search engine which has been running since July, 2004.
#     The dataset is provided by the academic comunity for research purposes in data mining (clustering, classification, etc),
#     information retrieval (ranking, search, etc), xml, data compression, data streaming,
#     and any other non-commercial activity.
#     For more information, please refer to the link http://www.di.unipi.it/~gulli/AG_corpus_of_news_articles.html .
#
#     The AG's news topic classification dataset is constructed by Xiang Zhang (xiang.zhang@nyu.edu) from the dataset above.
#     It is used as a text classification benchmark in the following paper:
#     Xiang Zhang, Junbo Zhao, Yann LeCun. Character-level Convolutional Networks for Text Classification. Advances in Neural Information Processing Systems 28 (NIPS 2015).
#
#     The AG's news topic classification dataset is constructed by choosing 4 largest classes from the original corpus.
#     Each class contains 30,000 training samples and 1,900 testing samples.
#     The total number of training samples is 120,000 and testing 7,600.
#     """,
#     homepage='https://arxiv.org/abs/1509.01626',
#     data_path='/root/tensorflow_datasets/ag_news_subset/1.0.0',
#     file_format=tfrecord,
#     download_size=11.24 MiB,
#     dataset_size=35.79 MiB,
#     features=FeaturesDict({
#         'description': Text(shape=(), dtype=tf.string),
#         'label': ClassLabel(shape=(), dtype=tf.int64, num_classes=4),
#         'title': Text(shape=(), dtype=tf.string),
#     }),
#     supervised_keys=('description', 'label'),
#     disable_shuffling=False,
#     splits={
#         'test': <SplitInfo num_examples=7600, num_shards=1>,
#         'train': <SplitInfo num_examples=120000, num_shards=1>,
#     },
#     citation="""@misc{zhang2015characterlevel,
#         title={Character-level Convolutional Networks for Text Classification},
#         author={Xiang Zhang and Junbo Zhao and Yann LeCun},
#         year={2015},
#         eprint={1509.01626},
#         archivePrefix={arXiv},
#         primaryClass={cs.LG}
#     }""",
# )

# %% [markdown]
# ### Deep learning for text

# %% [markdown]
# #### Natural-language processing: The bird's eye view

# %% [markdown]
# Handcrafted rules held out as the dominant approach well into the 1990s. But starting in the late 1980s, faster computers and greater data availability started making a better alternative viable.

# %% [markdown]
# We started seeing machine learning approaches to natural language processing. The earliest ones were based on `decision trees`—the intent was literally to automate the development of the kind of if/then/else rules of previous systems

# %% [markdown]
# Then statistical approaches started gaining speed, starting with `logistic regression`. Over time, learned parametric models fully took over, and linguistics came to be seen as more of a hindrance than a useful tool.

# %% [markdown]
# In early 2015, Keras made available the first open source, easy-to-use implementation of `LSTM`, just at the start of a massive wave of renewed interest in recurrent neural networks—until then, there had only been “research code” that couldn’t be readily reused.

# %% [markdown]
# Then from 2015 to 2017, recurrent neural networks dominated the booming NLP scene. `Bidirectional LSTM` models, in particular, set the state of the art on many important tasks, from summarization to question-answering to machine translation.

# %% [markdown]
# Finally, around 2017–2018, a new architecture rose to replace RNNs: the `Transformer`. Transformers unlocked considerable progress across the field in a short period of time, and today most NLP systems are based on them.

# %% [markdown]
# ### Common Natural Language Processing Tasks
#
# The applications of natural language algorithms are commonly called tasks. Here are some popular tasks:
#
# 1. **Sentiment Analysis**: Given opinionated text like a movie review, determine whether the overall sense is positive or negative.
# 2. **Translation**: Turn text into another language.
# Answer Questions: Answer questions about the text, like who is the hero, or what actions occurred.
# 3. **Summarize or Paraphrase**: Provide a short overview of the text, emphasizing the main points.
# 4. **Generate New Text**: Given some starting text, write more text that seems to follow from it.
# 5. **Logical Flow**: If a sentence first asserts a premise and the following sentence asserts a conclusion based on that premise, determine whether the conclusion logically follows from the premise.

# %% [markdown]
# ### Preparing text data

# %% [markdown]
# <img src="https://github.com/djp840/MSDS_458_Public/blob/master/images/11-01.png?raw=1">

# %% [markdown]
# #### Text standardization

# %% [markdown]
# Text standardization is a basic form of feature engineering that aims to erase encoding differences that you don’t want your model to have to deal with. It’s not exclusive to machine learning, either—you’d have to do the same thing if you were building a search engine.

# %% [markdown]
# One of the simplest and most widespread standardization schemes is “convert to lowercase and remove punctuation characters.”

# %% [markdown]
# With these standardization techniques, your model will require less training data and will generalize better—it won’t need abundant examples of both “Sunset” and “sunset” to learn that they mean the same thing...

# %% [markdown]
# #### Text splitting (tokenization)

# %% [markdown]
# Once your text is standardized, you need to break it up into units to be vectorized (tokens), a step called tokenization. You could do this in three different ways:
#
# * `Word-level tokenization`—Where tokens are space-separated (or punctuation-separated) substrings. A variant of this is to further split words into subwords when applicable—for instance, treating “staring” as “star+ing” or “called” as “call+ed.”
# * `N-gram tokenization`—Where tokens are groups of N consecutive words. For instance, “the cat” or “he was” would be 2-gram tokens (also called bigrams).
# * `Character-level tokenization`—Where each character is its own token. In practice, this scheme is rarely used, and you only really see it in specialized contexts, like text generation or speech recognition.

# %% [markdown]
# Here’s a simple example. Consider the sentence “the cat sat on the mat.” It may be decomposed into the following set of 2-grams:
#
# `{"the", "the cat", "cat", "cat sat", "sat",
#  "sat on", "on", "on the", "the mat", "mat"}`

# %% [markdown]
# It may also be decomposed into the following set of 3-grams:
#
# `{"the", "the cat", "cat", "cat sat", "the cat sat",
#  "sat", "sat on", "on", "cat sat on", "on the",
#  "sat on the", "the mat", "mat", "on the mat"}`

# %% [markdown]
# `One-dimensional convnets`, `recurrent neural networks`, and `Transformers` are capable of learning representations for groups of words and characters without being explicitly told about the existence of such groups, by looking at continuous word or character sequences.

# %% [markdown]
# #### Vocabulary indexing

# %% [markdown]
# 1. Build an index of all terms found in the training data (the “vocabulary”), and assign a unique integer to each entry in the vocabulary.
# ```python
# vocabulary = {}
# for text in dataset:
#     text = standardize(text)
#     tokens = tokenize(text)
#     for token in tokens:
#         if token not in vocabulary:
#             vocabulary[token] = len(vocabulary)
# ```

# %% [markdown]
# 2. You can then convert that integer into a vector encoding that can be processed by a neural network, like a one-hot vector:
# ```python
# def one_hot_encode_token(token):
#     vector = np.zeros((len(vocabulary),))
#     token_index = vocabulary[token]
#     vector[token_index] = 1
#     return vector
# ```

# %% [markdown]
# #### Using the TextVectorization layer

# %% [markdown]
# ```python
# import string
#
# class Vectorizer:
#     def standardize(self, text):
#         text = text.lower()
#         return "".join(char for char in text
#                        if char not in string.punctuation)
#
#     def tokenize(self, text):
#         text = self.standardize(text)
#         return text.split()
#
#     def make_vocabulary(self, dataset):
#         self.vocabulary = {"": 0, "[UNK]": 1}
#         for text in dataset:
#             text = self.standardize(text)
#             tokens = self.tokenize(text)
#             for token in tokens:
#                 if token not in self.vocabulary:
#                     self.vocabulary[token] = len(self.vocabulary)
#         self.inverse_vocabulary = dict(
#             (v, k) for k, v in self.vocabulary.items())
#
#     def encode(self, text):
#         text = self.standardize(text)
#         tokens = self.tokenize(text)
#         return [self.vocabulary.get(token, 1) for token in tokens]
#
#     def decode(self, int_sequence):
#         return " ".join(
#             self.inverse_vocabulary.get(i, "[UNK]") for i in int_sequence)
#
# vectorizer = Vectorizer()
# # Haiku by poet Hokushi
# dataset = [
#     "I write, erase, rewrite",
#     "Erase again, and then",
#     "A poppy blooms.",
# ]
# vectorizer.make_vocabulary(dataset)
# ```

# %% [markdown]
# ```python
# >>> test_sentence = "I write, rewrite, and still rewrite again"
# >>> encoded_sentence = vectorizer.encode(test_sentence)
# >>> print(encoded_sentence)
# [2, 3, 5, 7, 1, 5, 6]
# >>> decoded_sentence = vectorizer.decode(encoded_sentence)
# >>> print(decoded_sentence)
# "i write rewrite and [UNK] rewrite again"
# ```

# %% [markdown]
# However, using something like this wouldn’t be very performant. In practice, you’ll work with the Keras `TextVectorization` layer, which is fast and efficient and can be dropped directly into a `tf.data` pipeline or a Keras model.

# %% [markdown]
# ```python
# from tensorflow.keras.layers import TextVectorization
# text_vectorization = TextVectorization(
#     output_mode="int",    # Configures the layer to return sequences of words encoded as integer indices.
# )

# %% [markdown]
# By default, the `TextVectorization` layer will use the setting “convert to lowercase and remove punctuation” for text standardization, and “split on whitespace” for tokenization.

# %% [markdown]
# ```python
# import re
# import string
# import tensorflow as tf
#
# def custom_standardization_fn(string_tensor):
#     lowercase_string = tf.strings.lower(string_tensor)              ❶
#     return tf.strings.regex_replace(                                ❷
#         lowercase_string, f"[{re.escape(string.punctuation)}]", "")
#
# def custom_split_fn(string_tensor):
#     return tf.strings.split(string_tensor)                          ❸
#
# text_vectorization = TextVectorization(
#     output_mode="int",
#     standardize=custom_standardization_fn,
#     split=custom_split_fn,
# )
# ```

# %% [markdown]
# ❶ Convert strings to lowercase.
#
# ❷ Replace punctuation characters with the empty string.
#
# ❸ Split strings on whitespace.

# %% [markdown]
# To index the vocabulary of a text corpus, just call the `adapt()` method of the layer with a `Dataset` object that yields strings, or just with a list of Python strings:
# ```python
# dataset = [
#     "I write, erase, rewrite",
#     "Erase again, and then",
#     "A poppy blooms.",
# ]
# text_vectorization.adapt(dataset)
# ```

# %% [markdown]
# Note that you can retrieve the computed vocabulary via `get_vocabulary()`
# ```python
# >>> text_vectorization.get_vocabulary()
# ["", "[UNK]", "erase", "write", ...]
# ```

# %% [markdown]
# This method can be useful if you need to convert text encoded as integer sequences back into words. The first two entries in the vocabulary are the `mask` token (index 0) and the `OOV` token (index 1).
#
# Entries in the vocabulary list are sorted by frequency, so with a real-world dataset, very common words like “the” or “a” would come first.

# %% [markdown]
# #### Two ways we could use our `TextVectorization` layer

# %% [markdown]
# #####  The first option is to put it in the `tf.data pipeline`, like this:

# %% [markdown]
# There are two ways we could use our TextVectorization layer. The first option is to put it in the `tf.data pipeline`, like this:
# ```python
# int_sequence_dataset = string_dataset.map(   ❶
#     text_vectorization,
#     num_parallel_calls=4)                    ❷
# ```

# %% [markdown]
# ❶ string_dataset would be a dataset that yields string tensors.
#
# ❷ The num_parallel_calls argument is used to parallelize the map() call across multiple CPU cores.

# %% [markdown]
# ##### The second option is to make it part of the `model` (after all, it’s a Keras layer), like this:

# %% [markdown]
# The second option is to make it part of the model (after all, it’s a Keras layer), like this:
# ```python
# text_input = keras.Input(shape=(), dtype="string")             ❶
# vectorized_text = text_vectorization(text_input)               ❷
# embedded_input = keras.layers.Embedding(...)(vectorized_text)  ❸
# output = ...                                                   ❸
# model = keras.Model(text_input, output)
# ```
# ❶ Create a symbolic input that expects strings.
#
# ❷ Apply the text vectorization layer to it.
#
# ❸ You can keep chaining new layers on top—just your regular Functional API model.

# %% [markdown]
# ***There’s an important difference between the two**: if the vectorization step is part of the model, it will happen synchronously with the rest of the model. This means that at each training step, the rest of the model (placed on the GPU) will have to wait for the output of the TextVectorization layer (placed on the CPU) to be ready in order to get to work.

# %% [markdown]
# Meanwhile, putting the layer in the `tf.data` pipeline enables you to do asynchronous preprocessing of your data on CPU: while the GPU runs the model on one batch of vectorized data, the CPU stays busy by vectorizing the next batch of raw strings.

# %% [markdown]
# So if you’re training the model on GPU or TPU, you’ll probably want to go with the first option to get the best performance.

# %% [markdown]
# Now, if you were to export our model to a production environment, you would want to ship a model that accepts raw strings as input—otherwise you would have to reimplement text standardization and tokenization in your production environment (maybe in JavaScript?), and you would face the risk of introducing small preprocessing discrepancies that would hurt the model’s accuracy. Thankfully, the TextVectorization layer enables you to include text preprocessing right into your model, making it easier to deploy.

# %% [markdown]
# #### Exporting a model that processes raw strings

# %% [markdown]
# ```python
# inputs = keras.Input(shape=(1,), dtype="string")   ❶
# processed_inputs = text_vectorization(inputs)      ❷
# outputs = model(processed_inputs)                  ❸
# inference_model = keras.Model(inputs, outputs)     ❹
# ```

# %% [markdown]
# ❶ One input sample would be one string.
#
# ❷ Apply text preprocessing.
#
# ❸ Apply the previously trained model.
#
# ❹ Instantiate the end-to-end model.

# %% [markdown]
# The resulting model can process batches of `raw strings`:
# ```python
# import tensorflow as tf
# raw_text_data = tf.convert_to_tensor([
#     ["That was an excellent movie, I loved it."],
# ])
# predictions = inference_model(raw_text_data)
# print(f"{float(predictions[0] * 100):.2f} percent positive")
# ```

# %% [markdown]
# #### Verify TensorFlow Version and Keras Version

# %%
print("This notebook requires TensorFlow 2.0 or above")
print("TensorFlow version: ", tf.__version__)
assert version.parse(tf.__version__).release[0] >=2
# Out:
# This notebook requires TensorFlow 2.0 or above
# TensorFlow version:  2.9.2

# %%
print("Keras version: ", keras.__version__)
# Out:
# Keras version:  2.9.0

# %% [markdown]
# #### Mount Google Drive to Colab Environment

# %%
#from google.colab import drive
#drive.mount('/content/gdrive')

# %% [markdown]
# #### Visualization Utility Functions

# %%
def print_validation_report(test_labels, predictions):
    print("Classification Report")
    print(classification_report(test_labels, predictions))
    print('Accuracy Score: {}'.format(accuracy_score(test_labels, predictions)))
    print('Root Mean Square Error: {}'.format(np.sqrt(MSE(test_labels, predictions)))) 
    
def plot_confusion_matrix(y_true, y_pred):
    mtx = confusion_matrix(y_true, y_pred)
    fig, ax = plt.subplots(figsize=(8,8))
    sns.heatmap(mtx, annot=True, fmt='d', linewidths=.75,  cbar=False, ax=ax,cmap='Blues',linecolor='white')
    #  square=True,
    plt.ylabel('true label')
    plt.xlabel('predicted label')

def plot_graphs(history, metric):
  plt.plot(history.history[metric])
  plt.plot(history.history['val_'+metric], '')
  plt.xlabel("Epochs")
  plt.ylabel(metric)
  plt.legend([metric, 'val_'+metric])

# %% [markdown]
# #### Vectorization Class

# %%
class Vectorizer:
    def standardize(self, text):
        text = text.lower()
        return "".join(char for char in text if char not in string.punctuation)

    def tokenize(self, text):
        text = self.standardize(text)
        return text.split()

    def make_vocabulary(self, dataset):
        self.vocabulary = {"": 0, "[UNK]": 1}
        for text in dataset:
            text = self.standardize(text)
            tokens = self.tokenize(text)
            for token in tokens:
                if token not in self.vocabulary:
                    self.vocabulary[token] = len(self.vocabulary)
        self.inverse_vocabulary = dict(
            (v, k) for k, v in self.vocabulary.items())

    def encode(self, text):
        text = self.standardize(text)
        tokens = self.tokenize(text)
        return [self.vocabulary.get(token, 1) for token in tokens]

    def decode(self, int_sequence):
        return " ".join(
            self.inverse_vocabulary.get(i, "[UNK]") for i in int_sequence)

# %% [markdown]
# ### Display The Number of Batches

# %%
len(train_ds), len(val_ds), len(test_ds)
# Out:
# (3563, 188, 238)

# %% [markdown]
# ### Displaying The Shapes and Dtypes of the First Batch

# %% [raw]
# 'description': Text(shape=(), dtype=tf.string),
# 'label': ClassLabel(shape=(), dtype=tf.int64, num_classes=4),
# 'title': Text(shape=(), dtype=tf.string),

# %%
for inputs, targets in train_ds:
    print("inputs.shape:", inputs.shape)
    print()
    print("inputs.dtype:", inputs.dtype)
    print()
    print("targets.shape:", targets.shape)
    print()
    print("targets.dtype:", targets.dtype)
    print()
    print("inputs[0]:", inputs[0])
    print()
    print("targets[0]:", targets[0])
    break
# Out:
# inputs.shape: (32,)
#
# inputs.dtype: <dtype: 'string'>
#
# targets.shape: (32,)
#
# targets.dtype: <dtype: 'int64'>
#
# inputs[0]: tf.Tensor(b'AMD #39;s new dual-core Opteron chip is designed mainly for corporate computing applications, including databases, Web services, and financial transactions.', shape=(), dtype=string)
#
# targets[0]: tf.Tensor(3, shape=(), dtype=int64)

# %% [markdown]
# ### Stop words and Text vectorization

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <b>tf.keras.layers.TextVectorization</b><br>
#     https://www.tensorflow.org/api_docs/python/tf/keras/layers/TextVectorization
#     </div>

# %%
def custom_stopwords(input_text):
    lowercase = tf.strings.lower(input_text)
    stripped_punct = tf.strings.regex_replace(lowercase
                                  ,'[%s]' % re.escape(string.punctuation)
                                  ,'')
    return tf.strings.regex_replace(stripped_punct, r'\b(' + r'|'.join(STOPWORDS) + r')\b\s*',"")

# %%
nltk.download('stopwords')
STOPWORDS = stopwords.words("english")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
text_only_train_ds = train_ds.map(lambda x, y: x)

# %%
# Text Vectorizer

max_length = 150
max_tokens = 1000
text_vectorization = layers.TextVectorization(
    max_tokens=max_tokens,
    output_mode="int",
   # output_sequence_length=max_length,
    standardize=custom_stopwords
)
text_vectorization.adapt(text_only_train_ds)

int_train_ds = train_ds.map(
    lambda x, y: (text_vectorization(x), y),
    num_parallel_calls=4)
int_val_ds = val_ds.map(
    lambda x, y: (text_vectorization(x), y),
    num_parallel_calls=4)
int_test_ds = test_ds.map(
    lambda x, y: (text_vectorization(x), y),
    num_parallel_calls=4)

# %% [markdown]
# # Experiment C - 1D CNN

# %% [markdown]
# ## CNN_Model1
#
# No Regularization

# %%
inputs = tf.keras.Input(shape=(None,), dtype="int64")
embedded = tf.one_hot(inputs, depth=max_tokens)
x = layers.Conv1D(filters=32, kernel_size=3, activation='relu')(embedded)
x = layers.Dropout(0.5)(x)
x = layers.MaxPooling1D(pool_size=2)(x)
x = layers.GlobalMaxPooling1D()(x) 
x = layers.Dense(32, activation='relu')(x)
outputs = layers.Dense(4, activation="softmax")(x)
CNN_model1 = tf.keras.Model(inputs, outputs)


# model.compile(optimizer="rmsprop",
# loss="SparseCategoricalCrossentropy",
# metrics=["accuracy"])
# model.summary()

# %% [markdown]
# ### Making the Model

# %%
# All ConV1D parameters

# tf.keras.layers.Conv1D(
#     filters,
#     kernel_size,
#     strides=1,
#     padding='valid',
#     data_format='channels_last',
#     dilation_rate=1,
#     groups=1,
#     activation=None,
#     use_bias=True,
#     kernel_initializer='glorot_uniform',
#     bias_initializer='zeros',
#     kernel_regularizer=None,
#     bias_regularizer=None,
#     activity_regularizer=None,
#     kernel_constraint=None,
#     bias_constraint=None,
#     **kwargs
# )

# %%
# Define the model

CNN_model1= tf.keras.Sequential([
                           #  text_vectorization
                              tf.keras.layers.Embedding(input_dim=len(text_vectorization.get_vocabulary())
                              ,output_dim=32
                              ,mask_zero=True)
                              ,tf.keras.layers.Conv1D(
    filters=32,
    kernel_size=5,
)
                              ,tf.keras.layers.Dense(32, activation='relu')
                              ,tf.keras.layers.Dense(4,activation='softmax') # 4 classes: World, Sports, Business, Sci.Tech
                          #    ,kernel_regularizer=tf.keras.regularizers.L2(0.001) # Without Regularization
])

# %%
# compile the model

CNN_model1.compile(optimizer='adam'
              ,loss=tf.keras.losses.SparseCategoricalCrossentropy()
              ,metrics=['accuracy'])

# %%
# Fit the model

start_time = dt.now()
history = CNN_model1.fit(int_train_ds
                    ,epochs=200
                    ,validation_data=int_val_ds
                    ,validation_steps=10
                    ,callbacks=[tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=1)]
                    )
end_time = dt.now()
print(f'CNN_model1 fit time: {end_time-start_time}')
# Out:
# Epoch 1/200
# 3563/3563 [==============================] - 15s 4ms/step - loss: 0.5261 - accuracy: 0.8127 - val_loss: 0.4826 - val_accuracy: 0.8562
# Epoch 2/200
# 3563/3563 [==============================] - 15s 4ms/step - loss: 0.4189 - accuracy: 0.8494 - val_loss: 0.4621 - val_accuracy: 0.8531
# CNN_model1 fit time: 0:00:30.502306

# %%
CNN_model1.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, None)]            0
#
#  tf.one_hot_2 (TFOpLambda)   (None, None, 1000)        0
#
#  conv1d_2 (Conv1D)           (None, None, 32)          96032
#
#  dropout_2 (Dropout)         (None, None, 32)          0
#
#  max_pooling1d_2 (MaxPooling  (None, None, 32)         0
#  1D)
#
#  global_max_pooling1d_2 (Glo  (None, 32)               0
#  balMaxPooling1D)
#
#  dense_4 (Dense)             (None, 32)                1056
#
#  dense_5 (Dense)             (None, 4)                 132
#
# =================================================================
# Total params: 97,220
# Trainable params: 97,220
# Non-trainable params: 0
# _________________________________________________________________

# %%
CNN_model1.evaluate(int_test_ds)
# Out:
# 238/238 [==============================] - 2s 6ms/step - loss: 0.4723 - accuracy: 0.8493
# [0.4723268747329712, 0.8493421077728271]

# %%
history_dict = history.history
history_dict.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
history_df=pd.DataFrame(history_dict)
history_df.tail().round(3)
# Out:
#     loss  accuracy  val_loss  val_accuracy
# 0  0.526     0.813     0.483         0.856
# 1  0.419     0.849     0.462         0.853

# %% [markdown]
# ### Plot Training Metrics (Loss and Accuracy)

# %%
plot_history(history)

# %% [markdown]
# ### Confusion matrices
# Using both `sklearn.metrics`. Then we visualize the confusion matrix and see what that tells us.

# %%
pred1= CNN_model1.predict(int_test_ds)
pred1=np.argmax(pred1, axis=1)
# Out:
# 238/238 [==============================] - 1s 2ms/step

# %%
# print_validation_report(int_val_ds, pred1)

# %%
# plot_confusion_matrix(int_val_ds,pred1)
